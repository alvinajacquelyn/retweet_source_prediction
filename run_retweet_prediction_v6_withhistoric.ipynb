# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Merging features for non english set to 0

# %% [markdown]
# Informers

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_year_project/run_historic_features/mean/historic_features_FINAL_nonenglish_mean.csv')

# %%
df1.columns

# %%
df1 = df1.drop(['Unnamed: 0'], axis=1)

# %%
user_neg_mean = []
user_neu_mean = []
user_pos_mean = []
user_comp_mean = []
user_arts_culture_mean = []
user_business_entrepreneurs_mean = []
user_celebrity_pop_culture_mean = []
user_diaries_daily_life_mean = []
user_family_mean = []
user_fashion_style_mean = []
user_film_tv_video_mean = []
user_fitness_health_mean = []
user_food_dining_mean = []
user_gaming_mean = []
user_learning_educational_mean = []
user_music_mean = []
user_news_social_concern_mean = []
user_other_hobbies_mean = []
user_relationships_mean = []
user_science_technology_mean = []
user_sports_mean = []
user_travel_adventure_mean = []
user_youth_student_life_mean = []
user_hateful_mean = []
user_targeted_mean = []
user_aggressive_mean = []
user_joy_mean = []
user_sadness_mean = []
user_others_mean = []
user_anger_mean = []
user_surprise_mean = []
user_disgust_mean = []
user_fear_mean = []
user_topic_mode = []
politeness = []
tweet_subjectivity = []

# %% [markdown]
# check merged email

# %%
merged_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/final_year_project/merging_features/merged_df_renamed_FINAL.csv")
merged_df.columns

# %%
merged_df = merged_df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)

# %%
len(merged_df)
# Out:
# 6292

# %%
id = []
not_in = []
merged_df_copy = merged_df.copy()

# %%
for x in range(len(merged_df.index)):
    for y in range(len(df1.index)):
        if (merged_df.id[x]) == (df1.id[y]):
            id.append(df1.id[y])
            user_neg_mean.append(df1.user_neg_mean[y])
            user_neu_mean.append(df1.user_neu_mean[y])
            user_pos_mean.append(df1.user_pos_mean[y])
            user_comp_mean.append(df1.user_comp_mean[y])
            user_arts_culture_mean.append(df1['user_arts_&_culture_mean'][y])
            user_business_entrepreneurs_mean.append(df1['user_business_&_entrepreneurs_mean'][y])
            user_celebrity_pop_culture_mean.append(df1['user_celebrity_&_pop_culture_mean'][y])
            user_diaries_daily_life_mean.append(df1['user_diaries_&_daily_life_mean'][y])
            user_family_mean.append(df1['user_family_mean'][y])
            user_fashion_style_mean.append(df1['user_fashion_&_style_mean'][y])
            user_film_tv_video_mean.append(df1['user_film_tv_&_video_mean'][y])
            user_fitness_health_mean.append(df1['user_fitness_&_health_mean'][y])
            user_food_dining_mean.append(df1['user_food_&_dining_mean'][y])
            user_gaming_mean.append(df1['user_gaming_mean'][y])
            user_learning_educational_mean.append(df1['user_learning_&_educational_mean'][y])
            user_music_mean.append(df1['user_music_mean'][y])
            user_news_social_concern_mean.append(df1['user_news_&_social_concern_mean'][y])
            user_other_hobbies_mean.append(df1['user_other_hobbies_mean'][y])
            user_relationships_mean.append(df1['user_relationships_mean'][y])
            user_science_technology_mean.append(df1['user_science_&_technology_mean'][y])
            user_sports_mean.append(df1['user_sports_mean'][y])
            user_travel_adventure_mean.append(df1['user_travel_&_adventure_mean'][y])
            user_youth_student_life_mean.append(df1['user_youth_&_student_life_mean'][y])
            user_hateful_mean.append(df1['user_hateful_mean'][y])
            user_targeted_mean.append(df1['user_targeted_mean'][y])
            user_aggressive_mean.append(df1['user_aggressive_mean'][y])
            user_joy_mean.append(df1['user_joy_mean'][y])
            user_sadness_mean.append(df1.user_sadness_mean[y])
            user_others_mean.append(df1.user_others_mean[y])
            user_anger_mean.append(df1.user_anger_mean[y])
            user_surprise_mean.append(df1.user_surprise_mean[y])
            user_disgust_mean.append(df1.user_disgust_mean[y])
            user_fear_mean.append(df1.user_fear_mean[y])
            # user_topic_mode.append(df1.user_topic_mode[x])
            politeness.append(df1.politeness[y])
            tweet_subjectivity.append(df1.tweet_subjectivity[y])

    if merged_df.id[x] != id[-1]:
        not_in.append(merged_df.id[x])
        print(merged_df.id[x])
# Out:
# 1542616732556304386
# 199195386
# 994285612097261569
# 1320794886279438341
# 1483217045244334082
# 1312136927731159040
# 1553404799953027073
# 1484816006832869380
# 1548224277857517570
# 1273477452438929408
# 1376234816459444226
# 2827479370
# 1502114127883517955
# 1057197753233825793
# 1246065069026312198
# 1534264343994540032
# 1331022002640007169
# 1412039308731727873
# 1192447088132538373
# 399855217
# 1259998498050543616
# 1230887345462771713
# 1102275581541076998
# 1060977094644170752
# 1418595054684311553
# 1419958220542591001
# 1332977416080302082
# 1353265663385636864
# 1493176483019251713
# 1486137972521111553
# 1523991071885340673
# 1268144739997503493
# 1493122848851910659
# 928852100619964417
# 1167660096060395521
# 1541906272940830720
# 1437774760897875974
# 1380168103846367234
# 1492613070493044737
# 1219214266521096193
# 1105781477118304257
# 1087729678977241089
# 1430899835272454150
# 1172941914628382726
# 1515312308716769286
# 786994789
# 1398158248872583168
# ...

# %%
print(len(not_in))
# Out:
# 1396

# %%
print(len(id))
# Out:
# 4896

# %%
for x in range(len(merged_df_copy.index)):
    if (merged_df_copy.id[x]) in not_in:  
        merged_df_copy = merged_df_copy.drop(x, axis=0)

# %%
len(merged_df_copy)
# Out:
# 4896

# %%
len(user_neg_mean)
# Out:
# 4896

# %%
merged_df = merged_df_copy.copy()
len(merged_df)
# Out:
# 4896

# %%
len(merged_df.columns)
# Out:
# 117

# %%
merged_df['hist_normSentiment_neg'] = user_neg_mean 
merged_df['hist_normSentiment_neu'] = user_neu_mean 
merged_df['hist_normSentiment_pos'] = user_pos_mean 
merged_df['hist_normSentiment_comp'] = user_comp_mean
merged_df['hist_normTopic_arts&culture'] = user_arts_culture_mean 
merged_df['hist_normTopic_business&entrepreneurs'] = user_business_entrepreneurs_mean 
merged_df['hist_normTopic_celebrity&popculture'] = user_celebrity_pop_culture_mean 
merged_df['hist_normTopic_diaries&dailylife'] = user_diaries_daily_life_mean 
merged_df['hist_normTopic_family'] = user_family_mean 
merged_df['hist_normTopic_fashion&style'] = user_fashion_style_mean
merged_df['hist_normTopic_filmtv&video'] = user_film_tv_video_mean 
merged_df['hist_normTopic_fitness&health'] = user_fitness_health_mean 
merged_df['hist_normTopic_food&dining'] =user_food_dining_mean
merged_df['hist_normTopic_gaming'] = user_gaming_mean
merged_df['hist_normTopic_learning&educational'] =user_learning_educational_mean 
merged_df['hist_normTopic_music'] = user_music_mean
merged_df['hist_normTopic_news&socialconcern'] = user_news_social_concern_mean 
merged_df['hist_normTopic_otherhobbies'] = user_other_hobbies_mean 
merged_df['hist_normTopic_relationships'] = user_relationships_mean 
merged_df['hist_normTopic_science&technology'] = user_science_technology_mean
merged_df['hist_normTopic_sports'] = user_sports_mean
merged_df['hist_normTopic_travel&adventure'] = user_travel_adventure_mean 
merged_df['hist_normTopic_youth&studentlife'] = user_youth_student_life_mean
merged_df['hist_hateSpeech_hateful'] = user_hateful_mean 
merged_df['hist_hateSpeech_targeted'] = user_targeted_mean
merged_df['hist_hateSpeech_aggressiveness'] = user_aggressive_mean 
merged_df['hist_emotion_joy'] = user_joy_mean 
merged_df['hist_emotion_sadness'] = user_sadness_mean
merged_df['hist_emotion_other'] = user_others_mean 
merged_df['hist_emotion_anger'] = user_anger_mean 
merged_df['hist_emotion_surprise'] = user_surprise_mean 
merged_df['hist_emotion_disgust'] = user_disgust_mean
merged_df['hist_emotion_fear'] = user_fear_mean 
# merged_df['hisnormSentiment_neg'] = user_topic_mode 
merged_df['hist_politeness'] = politeness 
merged_df['hist_subjectivity'] = tweet_subjectivity

# %%
len(merged_df.columns)
# Out:
# 152

# %%
merged_df.reset_index(inplace=True)

# %%
merged_df.columns
# Out:
# Index(['level_0', 'index', 'id', 'hashtag', 'retweeter',
#        'user_daysAccountCreation', 'user_statusesCount', 'user_followersCount',
#        'user_favouritesCount', 'user_listCount',
#        ...
#        'hist_hateSpeech_aggressiveness', 'hist_emotion_joy',
#        'hist_emotion_sadness', 'hist_emotion_other', 'hist_emotion_anger',
#        'hist_emotion_surprise', 'hist_emotion_disgust', 'hist_emotion_fear',
#        'hist_politeness', 'hist_subjectivity'],
#       dtype='object', length=153)

# %%
# merged_df = merged_df.drop(['level_0'], axis=1)
merged_df.columns
# Out:
# Index(['index', 'id', 'hashtag', 'retweeter', 'user_daysAccountCreation',
#        'user_statusesCount', 'user_followersCount', 'user_favouritesCount',
#        'user_listCount', 'user_followingCount',
#        ...
#        'hist_hateSpeech_aggressiveness', 'hist_emotion_joy',
#        'hist_emotion_sadness', 'hist_emotion_other', 'hist_emotion_anger',
#        'hist_emotion_surprise', 'hist_emotion_disgust', 'hist_emotion_fear',
#        'hist_politeness', 'hist_subjectivity'],
#       dtype='object', length=152)

# %%
merged_df
# Out:
#       index                   id                    hashtag  \
# 0         0  1195757010723184640            #EnoughIsEnough
# 1         1           1159881870        #CostOfLivingCrisis
# 2         2   930520648245497856  #GetBackToWorkYouFatPonce
# 3         3            303324434  #GetBackToWorkYouFatPonce
# 4         4            345462945            #EnoughIsEnough
# ...     ...                  ...                        ...
# 4891   6287   900020453904977920  #GetBackToWorkYouFatPonce
# 4892   6288  1241742805195804673  #GetBackToWorkYouFatPonce
# 4893   6289   948998437093208065  #GetBackToWorkYouFatPonce
# 4894   6290  1517879830544629760  #GetBackToWorkYouFatPonce
# 4895   6291  1089814631303008256  #GetBackToWorkYouFatPonce
#
#                 retweeter  user_daysAccountCreation  user_statusesCount  \
# 0                48959540                      1006               18861
# 1     1051124876315152384                      3478               80450
# ...

# %%
merged_df = merged_df.drop(['index'], axis=1)

# %%
merged_df.to_csv("/content/drive/MyDrive/Colab Notebooks/final_year_project/run_prediction/merged_df_historic_features_nonenglish.csv")

# %% [markdown]
# retweeter

# %%
merged_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_year_project/run_prediction/merged_df_historic_features_nonenglish.csv')

# %%
merged_df
# Out:
#       Unnamed: 0                   id                    hashtag  \
# 0              0  1195757010723184640            #EnoughIsEnough
# 1              1           1159881870        #CostOfLivingCrisis
# 2              2   930520648245497856  #GetBackToWorkYouFatPonce
# 3              3            303324434  #GetBackToWorkYouFatPonce
# 4              4            345462945            #EnoughIsEnough
# ...          ...                  ...                        ...
# 4891        4891   900020453904977920  #GetBackToWorkYouFatPonce
# 4892        4892  1241742805195804673  #GetBackToWorkYouFatPonce
# 4893        4893   948998437093208065  #GetBackToWorkYouFatPonce
# 4894        4894  1517879830544629760  #GetBackToWorkYouFatPonce
# 4895        4895  1089814631303008256  #GetBackToWorkYouFatPonce
#
#                 retweeter  user_daysAccountCreation  user_statusesCount  \
# 0                48959540                      1006               18861
# ...

# %%
merged_df = merged_df.drop(['Unnamed: 0'], axis=1)

# %%
merged_df
# Out:
#                        id                    hashtag            retweeter  \
# 0     1195757010723184640            #EnoughIsEnough             48959540
# 1              1159881870        #CostOfLivingCrisis  1051124876315152384
# 2      930520648245497856  #GetBackToWorkYouFatPonce  1272622039220629504
# 3               303324434  #GetBackToWorkYouFatPonce           2912306735
# 4               345462945            #EnoughIsEnough  1072373029517316096
# ...                   ...                        ...                  ...
# 4891   900020453904977920  #GetBackToWorkYouFatPonce  1098611071705931779
# 4892  1241742805195804673  #GetBackToWorkYouFatPonce  1098611071705931779
# 4893   948998437093208065  #GetBackToWorkYouFatPonce  1098611071705931779
# 4894  1517879830544629760  #GetBackToWorkYouFatPonce  1440330790101929998
# 4895  1089814631303008256  #GetBackToWorkYouFatPonce   849276525560123393
#
#       user_daysAccountCreation  user_statusesCount  user_followersCount  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_year_project/run_historic_features/mean/historic_retweeter_features_FINAL_nonenglish_mean_v3.csv')

# %%
df2
# Out:
#      Unnamed: 0                   id  user_neg_mean  user_neu_mean  \
# 0             0  1072373029517316096       0.107141       0.751606
# 1             1   930520648245497856       0.090370       0.758020
# 2             2  1556317842160717825       0.127367       0.752908
# 3             3  1318942066517344258       0.055549       0.808434
# 4             4  1210180533050904577       0.108950       0.764760
# ..          ...                  ...            ...            ...
# 857         857  1446098596001161224       0.057670       0.743930
# 858         858  1205581929283817477       0.081889       0.684373
# 859         859  1303745818734866433       0.136511       0.697594
# 860         860  1486397215673397251       0.094195       0.739642
# 861         861  1349059004761337867       0.437000       0.563000
#
#      user_pos_mean  user_comp_mean  user_arts_&_culture_mean  \
# 0         0.090707       -0.030808                  0.018257
# ...

# %%
len(df2)
# Out:
# 862

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'id', 'user_neg_mean', 'user_neu_mean', 'user_pos_mean',
#        'user_comp_mean', 'user_arts_&_culture_mean',
#        'user_business_&_entrepreneurs_mean',
#        'user_celebrity_&_pop_culture_mean', 'user_diaries_&_daily_life_mean',
#        'user_family_mean', 'user_fashion_&_style_mean',
#        'user_film_tv_&_video_mean', 'user_fitness_&_health_mean',
#        'user_food_&_dining_mean', 'user_gaming_mean',
#        'user_learning_&_educational_mean', 'user_music_mean',
#        'user_news_&_social_concern_mean', 'user_other_hobbies_mean',
#        'user_relationships_mean', 'user_science_&_technology_mean',
#        'user_sports_mean', 'user_travel_&_adventure_mean',
#        'user_youth_&_student_life_mean', 'user_hateful_mean',
#        'user_targeted_mean', 'user_aggressive_mean', 'user_joy_mean',
#        'user_sadness_mean', 'user_others_mean', 'user_anger_mean',
#        'user_surprise_mean', 'user_disgust_mean', 'user_fear_mean',
# ...

# %%
df2= df2.drop(['Unnamed: 0'], axis=1)
df1= df1.drop(['Unnamed: 0'], axis=1)

# %%
ruser_neg_mean = []
ruser_neu_mean = []
ruser_pos_mean = []
ruser_comp_mean = []
ruser_arts_culture_mean = []
ruser_business_entrepreneurs_mean = []
ruser_celebrity_pop_culture_mean = []
ruser_diaries_daily_life_mean = []
ruser_family_mean = []
ruser_fashion_style_mean = []
ruser_film_tv_video_mean = []
ruser_fitness_health_mean = []
ruser_food_dining_mean = []
ruser_gaming_mean = []
ruser_learning_educational_mean = []
ruser_music_mean = []
ruser_news_social_concern_mean = []
ruser_other_hobbies_mean = []
ruser_relationships_mean = []
ruser_science_technology_mean = []
ruser_sports_mean = []
ruser_travel_adventure_mean = []
ruser_youth_student_life_mean = []
ruser_hateful_mean = []
ruser_targeted_mean = []
ruser_aggressive_mean = []
ruser_joy_mean = []
ruser_sadness_mean = []
ruser_others_mean = []
ruser_anger_mean = []
ruser_surprise_mean = []
ruser_disgust_mean = []
ruser_fear_mean = []
ruser_topic_mode = []
rpoliteness = []
rtweet_subjectivity = []

# %%
not_in_r = []
rid = []
not_in_hashtags = []
for x in range(len(merged_df.index)):
    if (merged_df.retweeter[x]) in df1.id.values:
        # df = df1.copy()
        for y in range(len(df1.index)):
            if (merged_df.retweeter[x]) == (df1.id[y]):
                rid.append(df1.id[y])
                ruser_neg_mean.append(df1.user_neg_mean[y])
                ruser_neu_mean.append(df1.user_neu_mean[y])
                ruser_pos_mean.append(df1.user_pos_mean[y])
                ruser_comp_mean.append(df1.user_comp_mean[y])
                ruser_arts_culture_mean.append(df1['user_arts_&_culture_mean'][y])
                ruser_business_entrepreneurs_mean.append(df1['user_business_&_entrepreneurs_mean'][y])
                ruser_celebrity_pop_culture_mean.append(df1['user_celebrity_&_pop_culture_mean'][y])
                ruser_diaries_daily_life_mean.append(df1['user_diaries_&_daily_life_mean'][y])
                ruser_family_mean.append(df1['user_family_mean'][y])
                ruser_fashion_style_mean.append(df1['user_fashion_&_style_mean'][y])
                ruser_film_tv_video_mean.append(df1['user_film_tv_&_video_mean'][y])
                ruser_fitness_health_mean.append(df1['user_fitness_&_health_mean'][y])
                ruser_food_dining_mean.append(df1['user_food_&_dining_mean'][y])
                ruser_gaming_mean.append(df1['user_gaming_mean'][y])
                ruser_learning_educational_mean.append(df1['user_learning_&_educational_mean'][y])
                ruser_music_mean.append(df1['user_music_mean'][y])
                ruser_news_social_concern_mean.append(df1['user_news_&_social_concern_mean'][y])
                ruser_other_hobbies_mean.append(df1['user_other_hobbies_mean'][y])
                ruser_relationships_mean.append(df1['user_relationships_mean'][y])
                ruser_science_technology_mean.append(df1['user_science_&_technology_mean'][y])
                ruser_sports_mean.append(df1['user_sports_mean'][y])
                ruser_travel_adventure_mean.append(df1['user_travel_&_adventure_mean'][y])
                ruser_youth_student_life_mean.append(df1['user_youth_&_student_life_mean'][y])
                ruser_hateful_mean.append(df1['user_hateful_mean'][y])
                ruser_targeted_mean.append(df1['user_targeted_mean'][y])
                ruser_aggressive_mean.append(df1['user_aggressive_mean'][y])
                ruser_joy_mean.append(df1['user_joy_mean'][y])
                ruser_sadness_mean.append(df1.user_sadness_mean[y])
                ruser_others_mean.append(df1.user_others_mean[y])
                ruser_anger_mean.append(df1.user_anger_mean[y])
                ruser_surprise_mean.append(df1.user_surprise_mean[y])
                ruser_disgust_mean.append(df1.user_disgust_mean[y])
                ruser_fear_mean.append(df1.user_fear_mean[y])
                # user_topic_mode.append(df1.user_topic_mode[x])
                rpoliteness.append(df1.politeness[y])
                rtweet_subjectivity.append(df1.tweet_subjectivity[y])
    elif (merged_df.retweeter[x]) in df2.id.values:
        # df = df2.copy()
        for y in range(len(df2.index)):
            if (merged_df.retweeter[x]) == (df2.id[y]):
                rid.append(df2.id[y])
                ruser_neg_mean.append(df2.user_neg_mean[y])
                ruser_neu_mean.append(df2.user_neu_mean[y])
                ruser_pos_mean.append(df2.user_pos_mean[y])
                ruser_comp_mean.append(df2.user_comp_mean[y])
                ruser_arts_culture_mean.append(df2['user_arts_&_culture_mean'][y])
                ruser_business_entrepreneurs_mean.append(df2['user_business_&_entrepreneurs_mean'][y])
                ruser_celebrity_pop_culture_mean.append(df2['user_celebrity_&_pop_culture_mean'][y])
                ruser_diaries_daily_life_mean.append(df2['user_diaries_&_daily_life_mean'][y])
                ruser_family_mean.append(df2['user_family_mean'][y])
                ruser_fashion_style_mean.append(df2['user_fashion_&_style_mean'][y])
                ruser_film_tv_video_mean.append(df2['user_film_tv_&_video_mean'][y])
                ruser_fitness_health_mean.append(df2['user_fitness_&_health_mean'][y])
                ruser_food_dining_mean.append(df2['user_food_&_dining_mean'][y])
                ruser_gaming_mean.append(df2['user_gaming_mean'][y])
                ruser_learning_educational_mean.append(df2['user_learning_&_educational_mean'][y])
                ruser_music_mean.append(df2['user_music_mean'][y])
                ruser_news_social_concern_mean.append(df2['user_news_&_social_concern_mean'][y])
                ruser_other_hobbies_mean.append(df2['user_other_hobbies_mean'][y])
                ruser_relationships_mean.append(df2['user_relationships_mean'][y])
                ruser_science_technology_mean.append(df2['user_science_&_technology_mean'][y])
                ruser_sports_mean.append(df2['user_sports_mean'][y])
                ruser_travel_adventure_mean.append(df2['user_travel_&_adventure_mean'][y])
                ruser_youth_student_life_mean.append(df2['user_youth_&_student_life_mean'][y])
                ruser_hateful_mean.append(df2['user_hateful_mean'][y])
                ruser_targeted_mean.append(df2['user_targeted_mean'][y])
                ruser_aggressive_mean.append(df2['user_aggressive_mean'][y])
                ruser_joy_mean.append(df2['user_joy_mean'][y])
                ruser_sadness_mean.append(df2.user_sadness_mean[y])
                ruser_others_mean.append(df2.user_others_mean[y])
                ruser_anger_mean.append(df2.user_anger_mean[y])
                ruser_surprise_mean.append(df2.user_surprise_mean[y])
                ruser_disgust_mean.append(df2.user_disgust_mean[y])
                ruser_fear_mean.append(df2.user_fear_mean[y])
                # user_topic_mode.append(df1.user_topic_mode[x])
                rpoliteness.append(df2.politeness[y])
                rtweet_subjectivity.append(df2.tweet_subjectivity[y])

    else:
        print(merged_df.retweeter[x])

        not_in_r.append(merged_df.retweeter[x])
        not_in_hashtags.append(merged_df.hashtag[x])

# %%
for x in range(len(merged_df.index)):
    if (merged_df.retweeter[x]) in not_in_r:  
        merged_df = merged_df.drop(x, axis=0)

# %%
len(merged_df)
# Out:
# 4896

# %%
merged_df['hist_r_normSentiment_neg'] = ruser_neg_mean 
merged_df['hist_r_normSentiment_neu'] = ruser_neu_mean 
merged_df['hist_r_normSentiment_pos'] = ruser_pos_mean 
merged_df['hist_r_normSentiment_comp'] = ruser_comp_mean
merged_df['hist_r_normTopic_arts&culture'] = ruser_arts_culture_mean 
merged_df['hist_r_normTopic_business&entrepreneurs'] = ruser_business_entrepreneurs_mean 
merged_df['hist_r_normTopic_celebrity&popculture'] = ruser_celebrity_pop_culture_mean 
merged_df['hist_r_normTopic_diaries&dailylife'] = ruser_diaries_daily_life_mean 
merged_df['hist_r_normTopic_family'] = ruser_family_mean 
merged_df['hist_r_normTopic_fashion&style'] = ruser_fashion_style_mean
merged_df['hist_r_normTopic_filmtv&video'] = ruser_film_tv_video_mean 
merged_df['hist_r_normTopic_fitness&health'] = ruser_fitness_health_mean 
merged_df['hist_r_normTopic_food&dining'] = ruser_food_dining_mean
merged_df['hist_r_normTopic_gaming'] = ruser_gaming_mean
merged_df['hist_r_normTopic_learning&educational'] = ruser_learning_educational_mean 
merged_df['hist_r_normTopic_music'] = ruser_music_mean
merged_df['hist_r_normTopic_news&socialconcern'] = ruser_news_social_concern_mean 
merged_df['hist_r_normTopic_otherhobbies'] = ruser_other_hobbies_mean 
merged_df['hist_r_normTopic_relationships'] = ruser_relationships_mean 
merged_df['hist_r_normTopic_science&technology'] = ruser_science_technology_mean
merged_df['hist_r_normTopic_sports'] = ruser_sports_mean
merged_df['hist_r_normTopic_travel&adventure'] = ruser_travel_adventure_mean 
merged_df['hist_r_normTopic_youth&studentlife'] = ruser_youth_student_life_mean
merged_df['hist_r_hateSpeech_hateful'] = ruser_hateful_mean 
merged_df['hist_r_hateSpeech_targeted'] = ruser_targeted_mean
merged_df['hist_r_hateSpeech_aggressiveness'] = ruser_aggressive_mean 
merged_df['hist_r_emotion_joy'] = ruser_joy_mean 
merged_df['hist_r_emotion_sadness'] = ruser_sadness_mean
merged_df['hist_r_emotion_other'] = ruser_others_mean 
merged_df['hist_r_emotion_anger'] = ruser_anger_mean 
merged_df['hist_r_emotion_surprise'] = ruser_surprise_mean 
merged_df['hist_r_emotion_disgust'] = ruser_disgust_mean
merged_df['hist_r_emotion_fear'] = ruser_fear_mean 
# merged_df['hist_normSentiment_neg'] = user_topic_mode 
merged_df['hist_r_politeness'] = rpoliteness 
merged_df['hist_r_subjectivity'] = rtweet_subjectivity

# %%
merged_df.to_csv('/content/drive/MyDrive/Colab Notebooks/final_year_project/run_prediction/merged_df_FINAL_NEW_nonenglish.csv')

# %%
print(merged_df.shape)
# Out:
# (4896, 186)

# %%
for x in merged_df.columns:
    print(x)
# Out:
# id
# hashtag
# retweeter
# user_daysAccountCreation
# user_statusesCount
# user_followersCount
# user_favouritesCount
# user_listCount
# user_followingCount
# user_normStatusesCount
# user_normFollowersCount
# user_normFavouritesCount
# user_normListCount
# user_normFollowingCount
# user_isVerified
# user_defaultPhoto
# user_hasURL
# user_tweetsCount
# user_retweetsCount
# user_repliesCount
# user_normTweetsCount
# user_normRetweetsCount
# user_normRepliesCount
# user_followsRetweeter
# user_mentionedRetweeterCount
# user_normMentionedRetweeterCount
# user_r_mentionedInf
# user_r_normMentionedInf
# retweeter_tweet
# tweet_normSentiment_neg
# tweet_normSentiment_neu
# tweet_normSentiment_pos
# tweet_normSentiment_comp
# tweet_normTopic_arts&culture
# tweet_normTopic_business&entrepreneurs
# tweet_normTopic_celebrity&popculture
# tweet_normTopic_diaries&dailylife
# tweet_normTopic_family
# tweet_normTopic_fashion&style
# tweet_normTopic_filmtv&video
# tweet_normTopic_fitness&health
# ...

# %% [markdown]
# # END

# %% [markdown]
# ## modify and merge features

# %%
# df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_retweeter_tweets_features_msc_mean.csv')
# df.head()
# df

# %%
# df.columns

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_features_retweeter_mean_FINAL_NEW_v3.csv')

# %%
# # for x in range(len(dftemp)):
# #     if 1072373029517316096 == dftemp.retweeter[x]:
# #         prin(ye))
# if 1072373029517316096 in dftemp.id.values:
#     print("Yes")

# %%
# df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_features_mean.csv')
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_features_retweeter_mean_FINAL_NEW.csv')
df1.id[0]
# Out:
# 48959540

# %%
df1
# Out:
#       Unnamed: 0                   id  user_neg_mean  user_neu_mean  \
# 0              0             48959540       0.095060       0.797190
# 1              1  1051124876315152384       0.109690       0.817440
# 2              2  1272622039220629504       0.081680       0.681810
# 3              3           2912306735       0.109939       0.782245
# 4              4  1072373029517315968       0.107141       0.751606
# ...          ...                  ...            ...            ...
# 3035        3035           1337470333       0.000000       1.000000
# 3036        3036           4275765797       0.084270       0.757000
# 3037        3037             25040839       0.084670       0.805050
# 3038        3038  1349059004761338112       0.437000       0.563000
# 3039        3039            118205346       0.014810       0.943000
#
#       user_pos_mean  user_comp_mean  user_arts_&_culture_mean  \
# 0          0.077760       -0.053128                  0.026322
# ...

# %%
df2
# Out:
#      Unnamed: 0                   id  user_neg_mean  user_neu_mean  \
# 0             0  1072373029517315968       0.107141       0.751606
# 1             1   930520648245497984       0.090370       0.758020
# 2             2  1556317842160717824       0.127367       0.752908
# 3             3  1318942066517344512       0.056110       0.816600
# 4             4  1210180533050904576       0.108950       0.764760
# ..          ...                  ...            ...            ...
# 857         857  1446098596001161216       0.057670       0.743930
# 858         858  1205581929283817472       0.083560       0.698340
# 859         859  1303745818734866432       0.137890       0.704640
# 860         860  1486397215673397248       0.098120       0.770460
# 861         861  1349059004761338112       0.437000       0.563000
#
#      user_pos_mean  user_comp_mean  user_arts_&_culture_mean  \
# 0         0.090707       -0.030808                  0.018257
# ...

# %%
#temp
# df1= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_tweets_temp.csv')
# df1

# %%
df2= df2.drop(['Unnamed: 0'], axis=1)
df1= df1.drop(['Unnamed: 0'], axis=1)

# %%
# merged_df_old = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Ziwen /features/sta/merged_df_renamed_FINAL.csv")
merged_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/merged_df_historic_features_NEW.csv")
merged_df
# Out:
#       Unnamed: 0  index                   id                    hashtag  \
# 0              0      0  1195757010723184640            #EnoughIsEnough
# 1              1      1           1159881870        #CostOfLivingCrisis
# 2              2      2   930520648245497856  #GetBackToWorkYouFatPonce
# 3              3      3            303324434  #GetBackToWorkYouFatPonce
# 4              4      4            345462945            #EnoughIsEnough
# ...          ...    ...                  ...                        ...
# 4891        4891   6287   900020453904977920  #GetBackToWorkYouFatPonce
# 4892        4892   6288  1241742805195804673  #GetBackToWorkYouFatPonce
# 4893        4893   6289   948998437093208065  #GetBackToWorkYouFatPonce
# 4894        4894   6290  1517879830544629760  #GetBackToWorkYouFatPonce
# 4895        4895   6291  1089814631303008256  #GetBackToWorkYouFatPonce
#
#                 retweeter  user_daysAccountCreation  user_statusesCount  \
# ...

# %%
merged_df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'id', 'hashtag', 'retweeter',
#        'user_daysAccountCreation', 'user_statusesCount', 'user_followersCount',
#        'user_favouritesCount', 'user_listCount',
#        ...
#        'hist_hateSpeech_aggressiveness', 'hist_emotion_joy',
#        'hist_emotion_sadness', 'hist_emotion_other', 'hist_emotion_anger',
#        'hist_emotion_surprise', 'hist_emotion_disgust', 'hist_emotion_fear',
#        'hist_politeness', 'hist_subjectivity'],
#       dtype='object', length=153)

# %%
merged_df = merged_df.drop(['Unnamed: 0'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-802e1fde7848> in <module>
# ----> 1 merged_df = merged_df.drop(['Unnamed: 0'], axis=1)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
merged_df
# Out:
#       index                   id                    hashtag  \
# 0         0  1195757010723184640            #EnoughIsEnough
# 1         1           1159881870        #CostOfLivingCrisis
# 2         2   930520648245497856  #GetBackToWorkYouFatPonce
# 3         3            303324434  #GetBackToWorkYouFatPonce
# 4         4            345462945            #EnoughIsEnough
# ...     ...                  ...                        ...
# 4891   6287   900020453904977920  #GetBackToWorkYouFatPonce
# 4892   6288  1241742805195804673  #GetBackToWorkYouFatPonce
# 4893   6289   948998437093208065  #GetBackToWorkYouFatPonce
# 4894   6290  1517879830544629760  #GetBackToWorkYouFatPonce
# 4895   6291  1089814631303008256  #GetBackToWorkYouFatPonce
#
#                 retweeter  user_daysAccountCreation  user_statusesCount  \
# 0                48959540                      1006               18861
# 1     1051124876315152384                      3478               80450
# ...

# %%
user_neg_mean = []
user_neu_mean = []
user_pos_mean = []
user_comp_mean = []
user_arts_culture_mean = []
user_business_entrepreneurs_mean = []
user_celebrity_pop_culture_mean = []
user_diaries_daily_life_mean = []
user_family_mean = []
user_fashion_style_mean = []
user_film_tv_video_mean = []
user_fitness_health_mean = []
user_food_dining_mean = []
user_gaming_mean = []
user_learning_educational_mean = []
user_music_mean = []
user_news_social_concern_mean = []
user_other_hobbies_mean = []
user_relationships_mean = []
user_science_technology_mean = []
user_sports_mean = []
user_travel_adventure_mean = []
user_youth_student_life_mean = []
user_hateful_mean = []
user_targeted_mean = []
user_aggressive_mean = []
user_joy_mean = []
user_sadness_mean = []
user_others_mean = []
user_anger_mean = []
user_surprise_mean = []
user_disgust_mean = []
user_fear_mean = []
user_topic_mode = []
politeness = []
tweet_subjectivity = []

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'id', 'user_neg_mean', 'user_neu_mean', 'user_pos_mean',
#        'user_comp_mean', 'user_arts_&_culture_mean',
#        'user_business_&_entrepreneurs_mean',
#        'user_celebrity_&_pop_culture_mean', 'user_diaries_&_daily_life_mean',
#        'user_family_mean', 'user_fashion_&_style_mean',
#        'user_film_tv_&_video_mean', 'user_fitness_&_health_mean',
#        'user_food_&_dining_mean', 'user_gaming_mean',
#        'user_learning_&_educational_mean', 'user_music_mean',
#        'user_news_&_social_concern_mean', 'user_other_hobbies_mean',
#        'user_relationships_mean', 'user_science_&_technology_mean',
#        'user_sports_mean', 'user_travel_&_adventure_mean',
#        'user_youth_&_student_life_mean', 'user_hateful_mean',
#        'user_targeted_mean', 'user_aggressive_mean', 'user_joy_mean',
#        'user_sadness_mean', 'user_others_mean', 'user_anger_mean',
#        'user_surprise_mean', 'user_disgust_mean', 'user_fear_mean',
# ...

# %%
df1 = df1.drop(['Unnamed: 0'], axis=1)

# %%
merged_df.reset_index
merged_df
# Out:
#                        id                    hashtag            retweeter  \
# 0     1195757010723184640            #EnoughIsEnough             48959540
# 1              1159881870        #CostOfLivingCrisis  1051124876315152384
# 2      930520648245497856  #GetBackToWorkYouFatPonce  1272622039220629504
# 3               303324434  #GetBackToWorkYouFatPonce           2912306735
# 4               345462945            #EnoughIsEnough  1072373029517316096
# ...                   ...                        ...                  ...
# 6287   900020453904977920  #GetBackToWorkYouFatPonce  1098611071705931779
# 6288  1241742805195804673  #GetBackToWorkYouFatPonce  1098611071705931779
# 6289   948998437093208065  #GetBackToWorkYouFatPonce  1098611071705931779
# 6290  1517879830544629760  #GetBackToWorkYouFatPonce  1440330790101929998
# 6291  1089814631303008256  #GetBackToWorkYouFatPonce   849276525560123393
#
#       user_daysAccountCreation  user_statusesCount  user_followersCount  \
# ...

# %%
df1
# Out:
#                        id  user_neg_mean  user_neu_mean  user_pos_mean  \
# 0                   17773       0.102100       0.750780       0.107130
# 1                  683063       0.094087       0.742232       0.076696
# 2                  708813       0.114070       0.785000       0.080890
# 3                  867681       0.101700       0.773580       0.114660
# 4                 1524781       0.059540       0.797930       0.102490
# ...                   ...            ...            ...            ...
# 6709  1558543081594650624       0.437000       0.563000       0.000000
# 6710  1558545466039599104       0.096545       0.749747       0.113283
# 6711  1559188363554463488       0.437000       0.563000       0.000000
# 6712  1559196468854112512       0.437000       0.563000       0.000000
# 6713  1559276934806266112       0.000000       1.000000       0.000000
#
#       user_comp_mean  user_arts_&_culture_mean  \
# 0           0.003709                  0.028045
# ...

# %%
if 1542616732556304386 in merged_df.id.values:
    print('yes')
# Out:
# yes

# %%
# df1.reset_index(level=None, drop=False, inplace=False, col_level=0, col_fill= '')
# print(df1)
# df1.id[3863]

# %%
# (merged_df.id[3863])
id = []
not_in = []

# %%
merged_df_copy = merged_df.copy()

# %%
type((df1.id[3]))
# Out:
# numpy.int64

# %%
len(merged_df.index)
# Out:
# 6292

# %%
len(df1.index)
# Out:
# 6714

# %%
for x in range(len(merged_df.index)):
    for y in range(len(df1.index)):
        if (merged_df.id[x]) == (df1.id[y]):
            id.append(df1.id[y])
            user_neg_mean.append(df1.user_neg_mean[y])
            user_neu_mean.append(df1.user_neu_mean[y])
            user_pos_mean.append(df1.user_pos_mean[y])
            user_comp_mean.append(df1.user_comp_mean[y])
            user_arts_culture_mean.append(df1['user_arts_&_culture_mean'][y])
            user_business_entrepreneurs_mean.append(df1['user_business_&_entrepreneurs_mean'][y])
            user_celebrity_pop_culture_mean.append(df1['user_celebrity_&_pop_culture_mean'][y])
            user_diaries_daily_life_mean.append(df1['user_diaries_&_daily_life_mean'][y])
            user_family_mean.append(df1['user_family_mean'][y])
            user_fashion_style_mean.append(df1['user_fashion_&_style_mean'][y])
            user_film_tv_video_mean.append(df1['user_film_tv_&_video_mean'][y])
            user_fitness_health_mean.append(df1['user_fitness_&_health_mean'][y])
            user_food_dining_mean.append(df1['user_food_&_dining_mean'][y])
            user_gaming_mean.append(df1['user_gaming_mean'][y])
            user_learning_educational_mean.append(df1['user_learning_&_educational_mean'][y])
            user_music_mean.append(df1['user_music_mean'][y])
            user_news_social_concern_mean.append(df1['user_news_&_social_concern_mean'][y])
            user_other_hobbies_mean.append(df1['user_other_hobbies_mean'][y])
            user_relationships_mean.append(df1['user_relationships_mean'][y])
            user_science_technology_mean.append(df1['user_science_&_technology_mean'][y])
            user_sports_mean.append(df1['user_sports_mean'][y])
            user_travel_adventure_mean.append(df1['user_travel_&_adventure_mean'][y])
            user_youth_student_life_mean.append(df1['user_youth_&_student_life_mean'][y])
            user_hateful_mean.append(df1['user_hateful_mean'][y])
            user_targeted_mean.append(df1['user_targeted_mean'][y])
            user_aggressive_mean.append(df1['user_aggressive_mean'][y])
            user_joy_mean.append(df1['user_joy_mean'][y])
            user_sadness_mean.append(df1.user_sadness_mean[y])
            user_others_mean.append(df1.user_others_mean[y])
            user_anger_mean.append(df1.user_anger_mean[y])
            user_surprise_mean.append(df1.user_surprise_mean[y])
            user_disgust_mean.append(df1.user_disgust_mean[y])
            user_fear_mean.append(df1.user_fear_mean[y])
            # user_topic_mode.append(df1.user_topic_mode[x])
            politeness.append(df1.politeness[y])
            tweet_subjectivity.append(df1.tweet_subjectivity[y])

    if merged_df.id[x] != id[-1]:
        not_in.append(merged_df.id[x])
        print(merged_df.id[x])
# Out:
# 1542616732556304386
# 199195386
# 994285612097261569
# 1320794886279438341
# 1483217045244334082
# 1312136927731159040
# 1553404799953027073
# 1484816006832869380
# 1548224277857517570
# 1273477452438929408
# 1376234816459444226
# 2827479370
# 1502114127883517955
# 1057197753233825793
# 1246065069026312198
# 1534264343994540032
# 1331022002640007169
# 1412039308731727873
# 1192447088132538373
# 399855217
# 1259998498050543616
# 1230887345462771713
# 1102275581541076998
# 1060977094644170752
# 1418595054684311553
# 1419958220542591001
# 1332977416080302082
# 1353265663385636864
# 1493176483019251713
# 1486137972521111553
# 1523991071885340673
# 1268144739997503493
# 1493122848851910659
# 928852100619964417
# 1167660096060395521
# 1541906272940830720
# 1437774760897875974
# 1380168103846367234
# 1492613070493044737
# 1219214266521096193
# 1105781477118304257
# 1087729678977241089
# 1430899835272454150
# 1172941914628382726
# 1515312308716769286
# 786994789
# 1398158248872583168
# ...

# %%
len(id)

# %%
print(len(not_in))

# %%
for x in range(len(merged_df_copy.index)):
    if (merged_df_copy.id[x]) in not_in:  
        merged_df_copy = merged_df_copy.drop(x, axis=0)

# %%
len(merged_df_copy)
# Out:
# 4896

# %%
merged_df_copy.reset_index(inplace=True)

# %%
for x in range(len(merged_df_copy.index)):
    if (merged_df_copy.retweeter[x]) in not_in_r:  
        merged_df_copy = merged_df_copy.drop(x, axis=0)

# %%
len(merged_df_copy)
# Out:
# 3870

# %%
merged_df_copy
# Out:
#       index  Unnamed: 0  Unnamed: 0.1                   id  \
# 0         0           0             0  1195757010723184640
# 1         1           1             1           1159881870
# 2         2           2             2   930520648245497856
# 3         3           3             3            303324434
# 4         4           4             4            345462945
# ...     ...         ...           ...                  ...
# 4890   6286        6286          4372  1329835583464673281
# 4891   6287        6287          4373   900020453904977920
# 4892   6288        6288          4374  1241742805195804673
# 4893   6289        6289          4375   948998437093208065
# 4894   6290        6290          4376  1517879830544629760
#
#                         hashtag            retweeter  \
# 0               #EnoughIsEnough             48959540
# 1           #CostOfLivingCrisis  1051124876315152384
# 2     #GetBackToWorkYouFatPonce  1272622039220629504
# ...

# %%
len(id)
# Out:
# 4896

# %%
merged_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'id', 'hashtag', 'retweeter',
#        'user_daysAccountCreation', 'user_statusesCount', 'user_followersCount',
#        'user_favouritesCount', 'user_listCount',
#        ...
#        'user_r_isVerified', 'user_r_defaultPhoto', 'user_r_hasURL',
#        'user_r_tweetsCount', 'user_r_retweetsCount', 'user_r_repliesCount',
#        'user_r_normTweetsCount', 'user_r_normRetweetsCount',
#        'user_r_normRepliesCount', 'retweeted_label'],
#       dtype='object', length=118)

# %%
hashtags = ['#VoteThemOut',
            # '#ToryScumOut',
            'F1',
            'Lisa',
            '#EnoughIsEnough',
            '#EnergyPrices',
            '#IOS16',
            '#taiwan',
            '#onepiece',
            '#CostofLivingCrisis',
            '#GetBackToworkYouFatPonce', 
            # '#ClosingCeremony',
            '#BookLoversDay',
            '#biden']
# add this 
# hashtags = ['F1']

for hash in hashtags:

    histdf = pd.read_csv(f'/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/{hash}.csv', encoding = 'utf-8') 
    if 199195386 in histdf.user_id.values:
        print("yes!, histdf", hash)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# yes!, histdf #EnoughIsEnough

# %%
histdf = pd.read_csv(f'/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/history_tweets_retweeter_msc.csv', encoding = 'utf-8') 
if 199195386 in histdf.id.values:
    print("yes!, histdf")

# %%
ruser_neg_mean = []
ruser_neu_mean = []
ruser_pos_mean = []
ruser_comp_mean = []
ruser_arts_culture_mean = []
ruser_business_entrepreneurs_mean = []
ruser_celebrity_pop_culture_mean = []
ruser_diaries_daily_life_mean = []
ruser_family_mean = []
ruser_fashion_style_mean = []
ruser_film_tv_video_mean = []
ruser_fitness_health_mean = []
ruser_food_dining_mean = []
ruser_gaming_mean = []
ruser_learning_educational_mean = []
ruser_music_mean = []
ruser_news_social_concern_mean = []
ruser_other_hobbies_mean = []
ruser_relationships_mean = []
ruser_science_technology_mean = []
ruser_sports_mean = []
ruser_travel_adventure_mean = []
ruser_youth_student_life_mean = []
ruser_hateful_mean = []
ruser_targeted_mean = []
ruser_aggressive_mean = []
ruser_joy_mean = []
ruser_sadness_mean = []
ruser_others_mean = []
ruser_anger_mean = []
ruser_surprise_mean = []
ruser_disgust_mean = []
ruser_fear_mean = []
ruser_topic_mode = []
rpoliteness = []
rtweet_subjectivity = []

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_features_retweeter_mean.csv')

df = df.drop(['Unnamed: 0'], axis=1)

# %%
df
# Out:
#                        id  user_neg_mean  user_neu_mean  user_pos_mean  \
# 0                   82283       0.009510       0.607940       0.012550
# 1                  639673       0.001040       0.504010       0.000000
# 2                  640893       0.106040       0.723899       0.139747
# 3                  989231       0.088150       0.728320       0.153580
# 4                 1233241       0.082070       0.893080       0.024850
# ...                   ...            ...            ...            ...
# 3858  1554254229056983040       0.038180       0.919580       0.012240
# 3859  1555233408800161793       0.008296       0.674735       0.051663
# 3860  1556317842160717825       0.127367       0.752908       0.119724
# 3861  1556624852852781057       0.013649       0.716412       0.094680
# 3862  1558147135681478659       0.088424       0.791960       0.119586
#
#       user_comp_mean  user_arts_&_culture_mean  \
# 0          -0.003227                  0.031967
# ...

# %%
len(df)
# Out:
# 3863

# %%
merged_df = merged_df.drop(['index'], axis = 1)
merged_df.columns
# Out:
# Index(['id', 'hashtag', 'retweeter', 'user_daysAccountCreation',
#        'user_statusesCount', 'user_followersCount', 'user_favouritesCount',
#        'user_listCount', 'user_followingCount', 'user_normStatusesCount',
#        ...
#        'hist_hateSpeech_aggressiveness', 'hist_emotion_joy',
#        'hist_emotion_sadness', 'hist_emotion_other', 'hist_emotion_anger',
#        'hist_emotion_surprise', 'hist_emotion_disgust', 'hist_emotion_fear',
#        'hist_politeness', 'hist_subjectivity'],
#       dtype='object', length=151)

# %%
merged_df
# Out:
#                        id                    hashtag            retweeter  \
# 0     1195757010723184640            #EnoughIsEnough             48959540
# 1              1159881870        #CostOfLivingCrisis  1051124876315152384
# 2      930520648245497856  #GetBackToWorkYouFatPonce  1272622039220629504
# 3               303324434  #GetBackToWorkYouFatPonce           2912306735
# 4               345462945            #EnoughIsEnough  1072373029517316096
# ...                   ...                        ...                  ...
# 4891   900020453904977920  #GetBackToWorkYouFatPonce  1098611071705931779
# 4892  1241742805195804673  #GetBackToWorkYouFatPonce  1098611071705931779
# 4893   948998437093208065  #GetBackToWorkYouFatPonce  1098611071705931779
# 4894  1517879830544629760  #GetBackToWorkYouFatPonce  1440330790101929998
# 4895  1089814631303008256  #GetBackToWorkYouFatPonce   849276525560123393
#
#       user_daysAccountCreation  user_statusesCount  user_followersCount  \
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_features_retweeter_mean_FINAL_NEW.csv')
df
# Out:
#       Unnamed: 0                   id  user_neg_mean  user_neu_mean  \
# 0              0             48959540       0.095060       0.797190
# 1              1  1051124876315152384       0.109690       0.817440
# 2              2  1272622039220629504       0.081680       0.681810
# 3              3           2912306735       0.109939       0.782245
# 4              4  1072373029517315968       0.107141       0.751606
# ...          ...                  ...            ...            ...
# 3035        3035           1337470333       0.000000       1.000000
# 3036        3036           4275765797       0.084270       0.757000
# 3037        3037             25040839       0.084670       0.805050
# 3038        3038  1349059004761338112       0.437000       0.563000
# 3039        3039            118205346       0.014810       0.943000
#
#       user_pos_mean  user_comp_mean  user_arts_&_culture_mean  \
# 0          0.077760       -0.053128                  0.026322
# ...

# %%
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#                        id  user_neg_mean  user_neu_mean  user_pos_mean  \
# 0                48959540       0.095060       0.797190       0.077760
# 1     1051124876315152384       0.109690       0.817440       0.072890
# 2     1272622039220629504       0.081680       0.681810       0.076470
# 3              2912306735       0.109939       0.782245       0.107816
# 4     1072373029517315968       0.107141       0.751606       0.090707
# ...                   ...            ...            ...            ...
# 3035           1337470333       0.000000       1.000000       0.000000
# 3036           4275765797       0.084270       0.757000       0.088740
# 3037             25040839       0.084670       0.805050       0.090280
# 3038  1349059004761338112       0.437000       0.563000       0.000000
# 3039            118205346       0.014810       0.943000       0.022190
#
#       user_comp_mean  user_arts_&_culture_mean  \
# 0          -0.053128                  0.026322
# ...

# %%
type(df.id[3])
# Out:
# numpy.int64

# %%
type(merged_df.retweeter[3])
# Out:
# numpy.int64

# %%
df.id.values
# Out:
# array([           48959540, 1051124876315152384, 1272622039220629504, ...,
#                   25040839, 1349059004761338112,           118205346])

# %%
merged_df.retweeter.values
# Out:
# array([           48959540, 1051124876315152384, 1272622039220629504, ...,
#        1098611071705931779, 1440330790101929998,  849276525560123393])

# %%
# if 1072373029517316096 in merged_df.retweeter.values:
#     print("yes")
# Out:
# yes

# %%
for x in range(len(merged_df)):
    if 1435553820382269441 == merged_df.retweeter[x]:
        print(merged_df.hashtag[x])
# Out:
# #EnoughIsEnough

# %%
hist =

# %%
if 1435553820382269441 in tdf.id.values.tolist():
    print("yes!, histdf")
# Out:
# yes!, histdf

# %%
tdf = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/redo_get_features.csv')

rt = tdf.id.values.tolist()

# %%
type(rt[3])
# Out:
# int

# %%
tweet_content =[]
ids= []
histdf = pd.read_csv(f'/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/#EnoughIsEnough.csv')
histdf
idxes = histdf.index[histdf['user_id'] == 1435553820382269441 ].tolist()
print(idxes)
if len(idxes) >100:
    idxes = idxes[:100]
for idx in idxes:
    tweet_content.append(histdf.tweet_content[idx])
    ids.append(histdf.user_id[idx])

print(tweet_content)
print(type(ids[2]))
new = pd.DataFrame(list(zip(ids,tweet_content)),
              columns=['id','text'])
print(new)
print(new.id[3])
# Out:
# [24401, 24402, 24403, 24404, 24405, 24406, 24407, 24408, 24409, 24410, 24411, 24412, 24413, 24414, 24415, 24416, 24417, 24418, 24419, 24420, 24421, 24422, 24423, 24424, 24425, 24426, 24427, 24428, 24429, 24430, 24431, 24432, 24433, 24434, 24435, 24436, 24437, 24438, 24439, 24440, 24441, 24442, 24443, 24444, 24445, 24446, 24447, 24448, 24449, 24450, 24451, 24452, 24453, 24454, 24455, 24456, 24457, 24458, 24459, 24460, 24461, 24462, 24463, 24464, 24465, 24466, 24467, 24468, 24469, 24470, 24471, 24472, 24473, 24474, 24475, 24476, 24477, 24478, 24479, 24480, 24481, 24482, 24483, 24484, 24485, 24486, 24487, 24488, 24489, 24490, 24491, 24492, 24493, 24494, 24495, 24496, 24497, 24498, 24499]
# ...

# %%
histdf.user_id[24401]
# Out:
# 1435553820382269441

# %%
if 1435553820382269441 in histdf.user_id.values:
    print("yes!, histdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b977bcfbc77b> in <module>
# ----> 1 if 1435553820382269441 in histdf.user_id.values:
#       2     print("yes!, histdf")
#
# NameError: name 'histdf' is not defined

# %%
df1
# Out:
#                        id  user_neg_mean  user_neu_mean  user_pos_mean  \
# 0                48959540       0.095060       0.797190       0.077760
# 1     1051124876315152384       0.109690       0.817440       0.072890
# 2     1272622039220629504       0.081680       0.681810       0.076470
# 3              2912306735       0.109939       0.782245       0.107816
# 4     1072373029517315968       0.107141       0.751606       0.090707
# ...                   ...            ...            ...            ...
# 3035           1337470333       0.000000       1.000000       0.000000
# 3036           4275765797       0.084270       0.757000       0.088740
# 3037             25040839       0.084670       0.805050       0.090280
# 3038  1349059004761338112       0.437000       0.563000       0.000000
# 3039            118205346       0.014810       0.943000       0.022190
#
#       user_comp_mean  user_arts_&_culture_mean  \
# 0          -0.053128                  0.026322
# ...

# %%
df2
# Out:
#                       id  user_neg_mean  user_neu_mean  user_pos_mean  \
# 0    1072373029517316096       0.107141       0.751606       0.090707
# 1     930520648245497856       0.090370       0.758020       0.081630
# 2    1556317842160717825       0.127367       0.752908       0.119724
# 3    1318942066517344258       0.056110       0.816600       0.117310
# 4    1210180533050904577       0.108950       0.764760       0.116310
# ..                   ...            ...            ...            ...
# 857  1446098596001161224       0.057670       0.743930       0.098380
# 858  1205581929283817477       0.083560       0.698340       0.088100
# 859  1303745818734866433       0.137890       0.704640       0.087490
# 860  1486397215673397251       0.098120       0.770460       0.091440
# 861  1349059004761337867       0.437000       0.563000       0.000000
#
#      user_comp_mean  user_arts_&_culture_mean  \
# 0         -0.030808                  0.018257
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df1.id.values
# Out:
# array([           48959540, 1051124876315152384, 1272622039220629504, ...,
#                   25040839, 1349059004761338112,           118205346])

# %%
not_in_r = []
rid = []
not_in_hashtags = []
for x in range(len(merged_df.index)):
    if (merged_df.retweeter[x]) in df1.id.values:
        # df = df1.copy()
        for y in range(len(df1.index)):
            if (merged_df.retweeter[x]) == (df1.id[y]):
                rid.append(df1.id[y])
                ruser_neg_mean.append(df1.user_neg_mean[y])
                ruser_neu_mean.append(df1.user_neu_mean[y])
                ruser_pos_mean.append(df1.user_pos_mean[y])
                ruser_comp_mean.append(df1.user_comp_mean[y])
                ruser_arts_culture_mean.append(df1['user_arts_&_culture_mean'][y])
                ruser_business_entrepreneurs_mean.append(df1['user_business_&_entrepreneurs_mean'][y])
                ruser_celebrity_pop_culture_mean.append(df1['user_celebrity_&_pop_culture_mean'][y])
                ruser_diaries_daily_life_mean.append(df1['user_diaries_&_daily_life_mean'][y])
                ruser_family_mean.append(df1['user_family_mean'][y])
                ruser_fashion_style_mean.append(df1['user_fashion_&_style_mean'][y])
                ruser_film_tv_video_mean.append(df1['user_film_tv_&_video_mean'][y])
                ruser_fitness_health_mean.append(df1['user_fitness_&_health_mean'][y])
                ruser_food_dining_mean.append(df1['user_food_&_dining_mean'][y])
                ruser_gaming_mean.append(df1['user_gaming_mean'][y])
                ruser_learning_educational_mean.append(df1['user_learning_&_educational_mean'][y])
                ruser_music_mean.append(df1['user_music_mean'][y])
                ruser_news_social_concern_mean.append(df1['user_news_&_social_concern_mean'][y])
                ruser_other_hobbies_mean.append(df1['user_other_hobbies_mean'][y])
                ruser_relationships_mean.append(df1['user_relationships_mean'][y])
                ruser_science_technology_mean.append(df1['user_science_&_technology_mean'][y])
                ruser_sports_mean.append(df1['user_sports_mean'][y])
                ruser_travel_adventure_mean.append(df1['user_travel_&_adventure_mean'][y])
                ruser_youth_student_life_mean.append(df1['user_youth_&_student_life_mean'][y])
                ruser_hateful_mean.append(df1['user_hateful_mean'][y])
                ruser_targeted_mean.append(df1['user_targeted_mean'][y])
                ruser_aggressive_mean.append(df1['user_aggressive_mean'][y])
                ruser_joy_mean.append(df1['user_joy_mean'][y])
                ruser_sadness_mean.append(df1.user_sadness_mean[y])
                ruser_others_mean.append(df1.user_others_mean[y])
                ruser_anger_mean.append(df1.user_anger_mean[y])
                ruser_surprise_mean.append(df1.user_surprise_mean[y])
                ruser_disgust_mean.append(df1.user_disgust_mean[y])
                ruser_fear_mean.append(df1.user_fear_mean[y])
                # user_topic_mode.append(df1.user_topic_mode[x])
                rpoliteness.append(df1.politeness[y])
                rtweet_subjectivity.append(df1.tweet_subjectivity[y])
    elif (merged_df.retweeter[x]) in df2.id.values:
        # df = df2.copy()
        for y in range(len(df2.index)):
            if (merged_df.retweeter[x]) == (df2.id[y]):
                rid.append(df2.id[y])
                ruser_neg_mean.append(df2.user_neg_mean[y])
                ruser_neu_mean.append(df2.user_neu_mean[y])
                ruser_pos_mean.append(df2.user_pos_mean[y])
                ruser_comp_mean.append(df2.user_comp_mean[y])
                ruser_arts_culture_mean.append(df2['user_arts_&_culture_mean'][y])
                ruser_business_entrepreneurs_mean.append(df2['user_business_&_entrepreneurs_mean'][y])
                ruser_celebrity_pop_culture_mean.append(df2['user_celebrity_&_pop_culture_mean'][y])
                ruser_diaries_daily_life_mean.append(df2['user_diaries_&_daily_life_mean'][y])
                ruser_family_mean.append(df2['user_family_mean'][y])
                ruser_fashion_style_mean.append(df2['user_fashion_&_style_mean'][y])
                ruser_film_tv_video_mean.append(df2['user_film_tv_&_video_mean'][y])
                ruser_fitness_health_mean.append(df2['user_fitness_&_health_mean'][y])
                ruser_food_dining_mean.append(df2['user_food_&_dining_mean'][y])
                ruser_gaming_mean.append(df2['user_gaming_mean'][y])
                ruser_learning_educational_mean.append(df2['user_learning_&_educational_mean'][y])
                ruser_music_mean.append(df2['user_music_mean'][y])
                ruser_news_social_concern_mean.append(df2['user_news_&_social_concern_mean'][y])
                ruser_other_hobbies_mean.append(df2['user_other_hobbies_mean'][y])
                ruser_relationships_mean.append(df2['user_relationships_mean'][y])
                ruser_science_technology_mean.append(df2['user_science_&_technology_mean'][y])
                ruser_sports_mean.append(df2['user_sports_mean'][y])
                ruser_travel_adventure_mean.append(df2['user_travel_&_adventure_mean'][y])
                ruser_youth_student_life_mean.append(df2['user_youth_&_student_life_mean'][y])
                ruser_hateful_mean.append(df2['user_hateful_mean'][y])
                ruser_targeted_mean.append(df2['user_targeted_mean'][y])
                ruser_aggressive_mean.append(df2['user_aggressive_mean'][y])
                ruser_joy_mean.append(df2['user_joy_mean'][y])
                ruser_sadness_mean.append(df2.user_sadness_mean[y])
                ruser_others_mean.append(df2.user_others_mean[y])
                ruser_anger_mean.append(df2.user_anger_mean[y])
                ruser_surprise_mean.append(df2.user_surprise_mean[y])
                ruser_disgust_mean.append(df2.user_disgust_mean[y])
                ruser_fear_mean.append(df2.user_fear_mean[y])
                # user_topic_mode.append(df1.user_topic_mode[x])
                rpoliteness.append(df2.politeness[y])
                rtweet_subjectivity.append(df2.tweet_subjectivity[y])

    else:
        print(merged_df.retweeter[x])

        not_in_r.append(merged_df.retweeter[x])
        not_in_hashtags.append(merged_df.hashtag[x])

# %%
len(rid)
# Out:
# 4896

# %%
# len(not_in)

# %%
len(not_in_r)
# Out:
# 0

# %%
merged_df_copy = merged_df.copy()

# %%
for x in range(len(merged_df.index)):
    if (merged_df.retweeter[x]) in not_in_r:  
        merged_df = merged_df.drop(x, axis=0)

# %%
len(merged_df)
# Out:
# 4896

# %%
merged_df
# Out:
#       index                   id                    hashtag  \
# 0         0  1195757010723184640            #EnoughIsEnough
# 1         1           1159881870        #CostOfLivingCrisis
# 2         2   930520648245497856  #GetBackToWorkYouFatPonce
# 3         3            303324434  #GetBackToWorkYouFatPonce
# 4         4            345462945            #EnoughIsEnough
# ...     ...                  ...                        ...
# 4891   6287   900020453904977920  #GetBackToWorkYouFatPonce
# 4892   6288  1241742805195804673  #GetBackToWorkYouFatPonce
# 4893   6289   948998437093208065  #GetBackToWorkYouFatPonce
# 4894   6290  1517879830544629760  #GetBackToWorkYouFatPonce
# 4895   6291  1089814631303008256  #GetBackToWorkYouFatPonce
#
#                 retweeter  user_daysAccountCreation  user_statusesCount  \
# 0                48959540                      1006               18861
# 1     1051124876315152384                      3478               80450
# ...

# %%
merged_df.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-e73907cf2264> in <module>
# ----> 1 merged_df_copy.reset_index(inplace=True)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5797                     )
#    5798
# -> 5799                 new_obj.insert(0, name, level_values)
#    5800
#    5801         new_obj.index = new_index
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
# ...

# %%
merged_df_copy.to_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/merged_df_FINAL_NEW_v3.csv')

# %%
len(not_in_hashtags)
# Out:
# 1315

# %%
no = pd.DataFrame(list(zip(not_in_hashtags, not_in_r)),
              columns=['hashtag','id'])
no.to_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/redo_get_features.csv')

# %%
merged_df['hist_r_normSentiment_neg'] = ruser_neg_mean 
merged_df['hist_r_normSentiment_neu'] = ruser_neu_mean 
merged_df['hist_r_normSentiment_pos'] = ruser_pos_mean 
merged_df['hist_r_normSentiment_comp'] = ruser_comp_mean
merged_df['hist_r_normTopic_arts&culture'] = ruser_arts_culture_mean 
merged_df['hist_r_normTopic_business&entrepreneurs'] = ruser_business_entrepreneurs_mean 
merged_df['hist_r_normTopic_celebrity&popculture'] = ruser_celebrity_pop_culture_mean 
merged_df['hist_r_normTopic_diaries&dailylife'] = ruser_diaries_daily_life_mean 
merged_df['hist_r_normTopic_family'] = ruser_family_mean 
merged_df['hist_r_normTopic_fashion&style'] = ruser_fashion_style_mean
merged_df['hist_r_normTopic_filmtv&video'] = ruser_film_tv_video_mean 
merged_df['hist_r_normTopic_fitness&health'] = ruser_fitness_health_mean 
merged_df['hist_r_normTopic_food&dining'] = ruser_food_dining_mean
merged_df['hist_r_normTopic_gaming'] = ruser_gaming_mean
merged_df['hist_r_normTopic_learning&educational'] = ruser_learning_educational_mean 
merged_df['hist_r_normTopic_music'] = ruser_music_mean
merged_df['hist_r_normTopic_news&socialconcern'] = ruser_news_social_concern_mean 
merged_df['hist_r_normTopic_otherhobbies'] = ruser_other_hobbies_mean 
merged_df['hist_r_normTopic_relationships'] = ruser_relationships_mean 
merged_df['hist_r_normTopic_science&technology'] = ruser_science_technology_mean
merged_df['hist_r_normTopic_sports'] = ruser_sports_mean
merged_df['hist_r_normTopic_travel&adventure'] = ruser_travel_adventure_mean 
merged_df['hist_r_normTopic_youth&studentlife'] = ruser_youth_student_life_mean
merged_df['hist_r_hateSpeech_hateful'] = ruser_hateful_mean 
merged_df['hist_r_hateSpeech_targeted'] = ruser_targeted_mean
merged_df['hist_r_hateSpeech_aggressiveness'] = ruser_aggressive_mean 
merged_df['hist_r_emotion_joy'] = ruser_joy_mean 
merged_df['hist_r_emotion_sadness'] = ruser_sadness_mean
merged_df['hist_r_emotion_other'] = ruser_others_mean 
merged_df['hist_r_emotion_anger'] = ruser_anger_mean 
merged_df['hist_r_emotion_surprise'] = ruser_surprise_mean 
merged_df['hist_r_emotion_disgust'] = ruser_disgust_mean
merged_df['hist_r_emotion_fear'] = ruser_fear_mean 
# merged_df['hist_normSentiment_neg'] = user_topic_mode 
merged_df['hist_r_politeness'] = rpoliteness 
merged_df['hist_r_subjectivity'] = rtweet_subjectivity

# %%
merged_df.columns
# Out:
# Index(['index', 'id', 'hashtag', 'retweeter', 'user_daysAccountCreation',
#        'user_statusesCount', 'user_followersCount', 'user_favouritesCount',
#        'user_listCount', 'user_followingCount',
#        ...
#        'hist_r_hateSpeech_aggressiveness', 'hist_r_emotion_joy',
#        'hist_r_emotion_sadness', 'hist_r_emotion_other',
#        'hist_r_emotion_anger', 'hist_r_emotion_surprise',
#        'hist_r_emotion_disgust', 'hist_r_emotion_fear', 'hist_r_politeness',
#        'hist_r_subjectivity'],
#       dtype='object', length=187)

# %%
merged_df.to_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/merged_df_FINAL_NEW_v3.csv')
