# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline

# %%
import re
import pandas as pd
import string
import spacy
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#!pip install wordcloud
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %% [markdown]
# # Comptuting mean for non english =0 csv file

# %% [markdown]
# Informer

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_year_project/run_historic_features/check_lang/historic_features_msc_FINAL_changed_nonenglish.csv')

# %%
len(df)
# Out:
# 430438

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'id',
#        'Unnamed: 0.1.1.1', 'text', 'grammartext', 'clean_text',
#        'user_neg_mean', 'user_neu_mean', 'user_pos_mean', 'user_comp_mean',
#        'user_arts_&_culture_mean', 'user_business_&_entrepreneurs_mean',
#        'user_celebrity_&_pop_culture_mean', 'user_diaries_&_daily_life_mean',
#        'user_family_mean', 'user_fashion_&_style_mean',
#        'user_film_tv_&_video_mean', 'user_fitness_&_health_mean',
#        'user_food_&_dining_mean', 'user_gaming_mean',
#        'user_learning_&_educational_mean', 'user_music_mean',
#        'user_news_&_social_concern_mean', 'user_other_hobbies_mean',
#        'user_relationships_mean', 'user_science_&_technology_mean',
#        'user_sports_mean', 'user_travel_&_adventure_mean',
#        'user_youth_&_student_life_mean', 'user_hateful_mean',
#        'user_targeted_mean', 'user_aggressive_mean', 'user_joy_mean',
# ...

# %%
df.user_neg_mean[133]
# Out:
# 0.0705268817204301

# %%
df = df.drop(['Unnamed: 0','Unnamed: 0.1', 'Unnamed: 0.1.1','Unnamed: 0.1.1.1'], axis =1)
df.columns
# Out:
# Index(['id', 'text', 'grammartext', 'clean_text', 'user_neg_mean',
#        'user_neu_mean', 'user_pos_mean', 'user_comp_mean',
#        'user_arts_&_culture_mean', 'user_business_&_entrepreneurs_mean',
#        'user_celebrity_&_pop_culture_mean', 'user_diaries_&_daily_life_mean',
#        'user_family_mean', 'user_fashion_&_style_mean',
#        'user_film_tv_&_video_mean', 'user_fitness_&_health_mean',
#        'user_food_&_dining_mean', 'user_gaming_mean',
#        'user_learning_&_educational_mean', 'user_music_mean',
#        'user_news_&_social_concern_mean', 'user_other_hobbies_mean',
#        'user_relationships_mean', 'user_science_&_technology_mean',
#        'user_sports_mean', 'user_travel_&_adventure_mean',
#        'user_youth_&_student_life_mean', 'user_hateful_mean',
#        'user_targeted_mean', 'user_aggressive_mean', 'user_joy_mean',
#        'user_sadness_mean', 'user_others_mean', 'user_anger_mean',
# ...

# %%
df.id
# Out:
# 0         1327956774192893952
# 1         1327956774192893952
# 2         1327956774192893952
# 3         1327956774192893952
# 4         1327956774192893952
#                  ...
# 430433              105011437
# 430434              105011437
# 430435              105011437
# 430436              105011437
# 430437              105011437
# Name: id, Length: 430438, dtype: int64

# %%
len(df.id.unique())
# Out:
# 3863

# %%
df1 = df.groupby(['id'], sort=False).mean().reset_index()

# %%
df1.to_csv('/content/drive/MyDrive/Colab Notebooks/final_year_project/run_historic_features/mean/historic_features_FINAL_nonenglish_mean.csv')

# %%
len(df1)
# Out:
# 3863

# %% [markdown]
# cHECKING MERGED

# %%
merged=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_year_project/historic_tweets/get_useful/merged_df_FINAL_NEW_v3.csv')

# %%
merged.columns
# Out:
# Index(['Unnamed: 0', 'index', 'id', 'hashtag', 'retweeter',
#        'user_daysAccountCreation', 'user_statusesCount', 'user_followersCount',
#        'user_favouritesCount', 'user_listCount',
#        ...
#        'hist_r_hateSpeech_aggressiveness', 'hist_r_emotion_joy',
#        'hist_r_emotion_sadness', 'hist_r_emotion_other',
#        'hist_r_emotion_anger', 'hist_r_emotion_surprise',
#        'hist_r_emotion_disgust', 'hist_r_emotion_fear', 'hist_r_politeness',
#        'hist_r_subjectivity'],
#       dtype='object', length=188)

# %%
len(merged.retweeter.unique())
# Out:
# 3040

# %%
test= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_year_project/run_historic_features/3/historic_retweeter_features_msc_FINAL_NEW_withpoliteness_subjectivity_v3.csv')

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_year_project/run_historic_features/3/historic_retweeter_features_msc_FINAL_NEW_withpoliteness_subjectivity_v3.csv')

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'id', 'Unnamed: 0.1.1', 'text',
#        'grammartext', 'clean_text', 'user_neg_mean', 'user_neu_mean',
#        'user_pos_mean', 'user_comp_mean', 'user_arts_&_culture_mean',
#        'user_business_&_entrepreneurs_mean',
#        'user_celebrity_&_pop_culture_mean', 'user_diaries_&_daily_life_mean',
#        'user_family_mean', 'user_fashion_&_style_mean',
#        'user_film_tv_&_video_mean', 'user_fitness_&_health_mean',
#        'user_food_&_dining_mean', 'user_gaming_mean',
#        'user_learning_&_educational_mean', 'user_music_mean',
#        'user_news_&_social_concern_mean', 'user_other_hobbies_mean',
#        'user_relationships_mean', 'user_science_&_technology_mean',
#        'user_sports_mean', 'user_travel_&_adventure_mean',
#        'user_youth_&_student_life_mean', 'user_hateful_mean',
#        'user_targeted_mean', 'user_aggressive_mean', 'user_joy_mean',
#        'user_sadness_mean', 'user_others_mean', 'user_anger_mean',
# ...

# %%
test.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'id', 'Unnamed: 0.1.1', 'text',
#        'grammartext', 'clean_text', 'user_neg_mean', 'user_neu_mean',
#        'user_pos_mean', 'user_comp_mean', 'user_arts_&_culture_mean',
#        'user_business_&_entrepreneurs_mean',
#        'user_celebrity_&_pop_culture_mean', 'user_diaries_&_daily_life_mean',
#        'user_family_mean', 'user_fashion_&_style_mean',
#        'user_film_tv_&_video_mean', 'user_fitness_&_health_mean',
#        'user_food_&_dining_mean', 'user_gaming_mean',
#        'user_learning_&_educational_mean', 'user_music_mean',
#        'user_news_&_social_concern_mean', 'user_other_hobbies_mean',
#        'user_relationships_mean', 'user_science_&_technology_mean',
#        'user_sports_mean', 'user_travel_&_adventure_mean',
#        'user_youth_&_student_life_mean', 'user_hateful_mean',
#        'user_targeted_mean', 'user_aggressive_mean', 'user_joy_mean',
#        'user_sadness_mean', 'user_others_mean', 'user_anger_mean',
# ...

# %%
len(test.id.unique())
# Out:
# 862

# %%
len(df1.id.unique())
# Out:
# 3040

# %% [markdown]
# Retweeter

# %%
# dfr = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_retweeter_features_msc_FINAL_changed_nonenglish.csv')

# %%
dfrv3 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_year_project/run_historic_features/check_lang/historic_retweeter_features_msc_FINAL_changed_nonenglish_v3.csv')

# %%
len(dfrv3)
# Out:
# 121126

# %%
dfrv3
# Out:
#         Unnamed: 0                   id  \
# 0                0  1072373029517316096
# 1                1  1072373029517316096
# 2                2  1072373029517316096
# 3                3  1072373029517316096
# 4                4  1072373029517316096
# ...            ...                  ...
# 121121      121121  1440330790101929998
# 121122      121122  1440330790101929998
# 121123      121123  1440330790101929998
# 121124      121124  1440330790101929998
# 121125      121125   849276525560123393
#
#                                                      text  \
# 0       If I was a Capitalist country I would be decon...
# 1       @AFP A comedian says some words. https://t.co/...
# 2                 RT @IanByrneMP: https://t.co/8uVYiFqQa5
# 3       @KevinPascoe @DailyMirror No surprise there Ke...
# 4       RT @KevinPascoe: @SundaySocialist @DailyMirror...
# ...                                                   ...
# 121121  @mrjamesob @PieroPasset ..oh I don’t know.Some...
# ...

# %%
dfrv3.columns
# Out:
# Index(['Unnamed: 0', 'id', 'text', 'grammartext', 'clean_text',
#        'user_neg_mean', 'user_neu_mean', 'user_pos_mean', 'user_comp_mean',
#        'user_arts_&_culture_mean', 'user_business_&_entrepreneurs_mean',
#        'user_celebrity_&_pop_culture_mean', 'user_diaries_&_daily_life_mean',
#        'user_family_mean', 'user_fashion_&_style_mean',
#        'user_film_tv_&_video_mean', 'user_fitness_&_health_mean',
#        'user_food_&_dining_mean', 'user_gaming_mean',
#        'user_learning_&_educational_mean', 'user_music_mean',
#        'user_news_&_social_concern_mean', 'user_other_hobbies_mean',
#        'user_relationships_mean', 'user_science_&_technology_mean',
#        'user_sports_mean', 'user_travel_&_adventure_mean',
#        'user_youth_&_student_life_mean', 'user_hateful_mean',
#        'user_targeted_mean', 'user_aggressive_mean', 'user_joy_mean',
#        'user_sadness_mean', 'user_others_mean', 'user_anger_mean',
# ...

# %%
dfrv3 = dfrv3.drop(['Unnamed: 0',], axis =1)
dfrv3.columns
# Out:
# Index(['id', 'text', 'grammartext', 'clean_text', 'user_neg_mean',
#        'user_neu_mean', 'user_pos_mean', 'user_comp_mean',
#        'user_arts_&_culture_mean', 'user_business_&_entrepreneurs_mean',
#        'user_celebrity_&_pop_culture_mean', 'user_diaries_&_daily_life_mean',
#        'user_family_mean', 'user_fashion_&_style_mean',
#        'user_film_tv_&_video_mean', 'user_fitness_&_health_mean',
#        'user_food_&_dining_mean', 'user_gaming_mean',
#        'user_learning_&_educational_mean', 'user_music_mean',
#        'user_news_&_social_concern_mean', 'user_other_hobbies_mean',
#        'user_relationships_mean', 'user_science_&_technology_mean',
#        'user_sports_mean', 'user_travel_&_adventure_mean',
#        'user_youth_&_student_life_mean', 'user_hateful_mean',
#        'user_targeted_mean', 'user_aggressive_mean', 'user_joy_mean',
#        'user_sadness_mean', 'user_others_mean', 'user_anger_mean',
# ...

# %%
len(dfrv3.id.unique())
# Out:
# 862

# %%
df3 = dfrv3.groupby(['id'], sort=False).mean().reset_index()
df3.to_csv('/content/drive/MyDrive/Colab Notebooks/final_year_project/run_historic_features/mean/historic_retweeter_features_FINAL_nonenglish_mean_v3.csv')

# %%
len(df3)
# Out:
# 862

# %% [markdown]
# End

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/history_tweets_retweeter_FINAL_FINAL.csv')
len(df1)
# Out:
# 458064

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_retweeter_features_msc_FINAL_NEW.csv')
len(df1)
# Out:
#   File "<ipython-input-5-b6953fd85b2e>", line 2
#     len(df1)
#     ^
# SyntaxError: invalid syntax

# %%
df =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_retweeter_features_msc_FINAL_withpoliteness_subjectivity_english.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-148c2939d709> in <module>
# ----> 1 df =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_retweeter_features_msc_FINAL_withpoliteness_subjectivity_english.csv')
#
# NameError: name 'pd' is not defined

# %%
# read informer/infector
# df = pd.read_csv(  '/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_features_msc_FINAL_withpoliteness_subjectivity.csv')
#read rter
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_retweeter_features_msc_FINAL_NEW_withpoliteness_subjectivity_v3.csv')

# %%
#temp test
# df = pd.read_csv( '/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_features_msc_FINAL.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'id',
#        'Unnamed: 0.1.1.1', 'text', 'grammartext', 'clean_text',
#        'user_neg_mean', 'user_neu_mean', 'user_pos_mean', 'user_comp_mean',
#        'user_arts_&_culture_mean', 'user_business_&_entrepreneurs_mean',
#        'user_celebrity_&_pop_culture_mean', 'user_diaries_&_daily_life_mean',
#        'user_family_mean', 'user_fashion_&_style_mean',
#        'user_film_tv_&_video_mean', 'user_fitness_&_health_mean',
#        'user_food_&_dining_mean', 'user_gaming_mean',
#        'user_learning_&_educational_mean', 'user_music_mean',
#        'user_news_&_social_concern_mean', 'user_other_hobbies_mean',
#        'user_relationships_mean', 'user_science_&_technology_mean',
#        'user_sports_mean', 'user_travel_&_adventure_mean',
#        'user_youth_&_student_life_mean', 'user_hateful_mean',
#        'user_targeted_mean', 'user_aggressive_mean', 'user_joy_mean',
# ...

# %%
dfrt=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_retweeter_features_msc_FINAL_withpoliteness_subjectivity_english.csv')

# %%
dfrt
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                   id  \
# 0               0             0               0  1072373029517316096
# 1               1             1               1  1072373029517316096
# 2               3             3               3  1072373029517316096
# 3               4             4               4  1072373029517316096
# 4               5             5               5  1072373029517316096
# ...           ...           ...             ...                  ...
# 75097      121121        121121          121121  1440330790101929998
# 75098      121122        121122          121122  1440330790101929998
# 75099      121123        121123          121123  1440330790101929998
# 75100      121124        121124          121124  1440330790101929998
# 75101      121125        121125          121125   849276525560123393
#
#        Unnamed: 0.1.1.1                                               text  \
# ...

# %%
dfi=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_features_msc_FINAL_withpoliteness_subjectivity_english.csv')

# %%
dfi
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                   id  \
# 0                0             0               0  1327956774192893952
# 1                1             1               1  1327956774192893952
# 2                2             2               2  1327956774192893952
# 3                3             3               3  1327956774192893952
# 4                4             4               4  1327956774192893952
# ...            ...           ...             ...                  ...
# 303696      430433        430433          430433            105011437
# 303697      430434        430434          430434            105011437
# 303698      430435        430435          430435            105011437
# 303699      430436        430436          430436            105011437
# 303700      430437        430437          430437            105011437
#
#         Unnamed: 0.1.1.1                                               text  \
# ...

# %%
dfi = dfi.drop(['Unnamed: 0', 'Unnamed: 0.1' , 'Unnamed: 0.1.1','Unnamed: 0.1.1.1'], axis=1)
dfrt = dfrt.drop(['Unnamed: 0', 'Unnamed: 0.1' , 'Unnamed: 0.1.1','Unnamed: 0.1.1.1'], axis=1)
#temp
# df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.head()
# Out:
#                     id                                               text  \
# 0  1072373029517316096  If I was a Capitalist country I would be decon...
# 1  1072373029517316096  @AFP A comedian says some words. https://t.co/...
# 2  1072373029517316096  @KevinPascoe @DailyMirror No surprise there Ke...
# 3  1072373029517316096  RT @KevinPascoe: @SundaySocialist @DailyMirror...
# 4  1072373029517316096  @BenWill1973 @Roppa77 @UKLabour How Tory infes...
#
#                                          grammartext  \
# 0  If I was a Capitalist country I would be decon...
# 1                         A comedian says some words
# 2  No surprise there Kev Milica Cosic joins the M...
# 3  I despair A paper that once employed John Pilg...
# 4  How Tory infested Push Polling will trash at t...
#
#                                           clean_text  user_neg_mean  \
# 0  if i was a capitalist country i would be decon...       0.107141
# ...

# %%
df
# Out:
#                         id                                               text  \
# 0      1072373029517316096  If I was a Capitalist country I would be decon...
# 1      1072373029517316096  @AFP A comedian says some words. https://t.co/...
# 2      1072373029517316096  @KevinPascoe @DailyMirror No surprise there Ke...
# 3      1072373029517316096  RT @KevinPascoe: @SundaySocialist @DailyMirror...
# 4      1072373029517316096  @BenWill1973 @Roppa77 @UKLabour How Tory infes...
# ...                    ...                                                ...
# 75097  1440330790101929998  @mrjamesob @PieroPasset ..oh I don’t know.Some...
# 75098  1440330790101929998  @TobiFrenzen @ChillaxBcn They will arrange ano...
# 75099  1440330790101929998  @CanalRiverTrust ..looks like a wee boatie on ...
# 75100  1440330790101929998  @1goodtern @E_catservant ..and why are you at ...
# 75101   849276525560123393  Sorry, you are not authorized to see the user ...
#
# ...

# %%
df.id[18]
# Out:
# 1072373029517316096

# %%
df.id = df.id.astype(int)

# %%
df.id[5]
# Out:
# 1072373029517315968

# %%
df.id
# Out:
# 0         1072373029517315968
# 1         1072373029517315968
# 2         1072373029517315968
# 3         1072373029517315968
# 4         1072373029517315968
#                  ...
# 120824    1440330790101929984
# 120825    1440330790101929984
# 120826    1440330790101929984
# 120827    1440330790101929984
# 120828     849276525560123392
# Name: id, Length: 120829, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'text', 'grammartext', 'clean_text', 'user_neg_mean',
#        'user_neu_mean', 'user_pos_mean', 'user_comp_mean',
#        'user_arts_&_culture_mean', 'user_business_&_entrepreneurs_mean',
#        'user_celebrity_&_pop_culture_mean', 'user_diaries_&_daily_life_mean',
#        'user_family_mean', 'user_fashion_&_style_mean',
#        'user_film_tv_&_video_mean', 'user_fitness_&_health_mean',
#        'user_food_&_dining_mean', 'user_gaming_mean',
#        'user_learning_&_educational_mean', 'user_music_mean',
#        'user_news_&_social_concern_mean', 'user_other_hobbies_mean',
#        'user_relationships_mean', 'user_science_&_technology_mean',
#        'user_sports_mean', 'user_travel_&_adventure_mean',
#        'user_youth_&_student_life_mean', 'user_hateful_mean',
#        'user_targeted_mean', 'user_aggressive_mean', 'user_joy_mean',
#        'user_sadness_mean', 'user_others_mean', 'user_anger_mean',
# ...

# %%
len(df)
# Out:
# 458064

# %%
dfrt
# Out:
#                         id                                               text  \
# 0      1072373029517316096  If I was a Capitalist country I would be decon...
# 1      1072373029517316096  @AFP A comedian says some words. https://t.co/...
# 2      1072373029517316096  @KevinPascoe @DailyMirror No surprise there Ke...
# 3      1072373029517316096  RT @KevinPascoe: @SundaySocialist @DailyMirror...
# 4      1072373029517316096  @BenWill1973 @Roppa77 @UKLabour How Tory infes...
# ...                    ...                                                ...
# 75097  1440330790101929998  @mrjamesob @PieroPasset ..oh I don’t know.Some...
# 75098  1440330790101929998  @TobiFrenzen @ChillaxBcn They will arrange ano...
# 75099  1440330790101929998  @CanalRiverTrust ..looks like a wee boatie on ...
# 75100  1440330790101929998  @1goodtern @E_catservant ..and why are you at ...
# 75101   849276525560123393  Sorry, you are not authorized to see the user ...
#
# ...

# %%
len(dfrt.id.unique())
# Out:
# 795

# %%
len(dfi.id.unique())
# Out:
# 3721

# %%
dfmerged=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/merged_df_FINAL_NEW_v3.csv')

# %%
dfmerged
# Out:
#       Unnamed: 0  index                   id                    hashtag  \
# 0              0      0  1195757010723184640            #EnoughIsEnough
# 1              1      1           1159881870        #CostOfLivingCrisis
# 2              2      2   930520648245497856  #GetBackToWorkYouFatPonce
# 3              3      3            303324434  #GetBackToWorkYouFatPonce
# 4              4      4            345462945            #EnoughIsEnough
# ...          ...    ...                  ...                        ...
# 4891        4891   6287   900020453904977920  #GetBackToWorkYouFatPonce
# 4892        4892   6288  1241742805195804673  #GetBackToWorkYouFatPonce
# 4893        4893   6289   948998437093208065  #GetBackToWorkYouFatPonce
# 4894        4894   6290  1517879830544629760  #GetBackToWorkYouFatPonce
# 4895        4895   6291  1089814631303008256  #GetBackToWorkYouFatPonce
#
#                 retweeter  user_daysAccountCreation  user_statusesCount  \
# ...

# %%
df1 = df.groupby(['id'], sort=False).mean().reset_index()

# %%
len(df1)
# Out:
# 795

# %%
df1.head()
# Out:
#                     id  user_neg_mean  user_neu_mean  user_pos_mean  \
# 0           4382946857       0.021122       0.787451       0.167012
# 1   982324460903682048       0.113870       0.758690       0.087420
# 2            286249825       0.071190       0.761250       0.127570
# 3  1324361363599273984       0.028050       0.610900       0.181060
# 4            532453867       0.119720       0.744520       0.105790
#
#    user_comp_mean  user_arts_&_culture_mean  \
# 0        0.297659                  0.057599
# 1       -0.058931                  0.035486
# 2        0.072530                  0.020435
# 3        0.176011                  0.057243
# 4        0.014324                  0.025022
#
#    user_business_&_entrepreneurs_mean  user_celebrity_&_pop_culture_mean  \
# 0                            0.153784                           0.032801
# 1                            0.037850                           0.067558
# ...

# %%
if 1435553820382269441 in df1.id.values:
    print("yes")
# Out:
# yes

# %%
if 849276525560123392 in df1.id.values:
    print("yes")

# %%
len(df1)
# Out:
# 3040

# %%
df1.id[5]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-051d462ee78f> in <module>
# ----> 1 df1.id[5]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'id'

# %%
print(df1.head)
# Out:
# <bound method NDFrame.head of                         user_neg_mean  user_neu_mean  user_pos_mean  \
# id
# 1.0000575391684812e+18       0.021770       0.931080       0.037150
# 1.0000706899011544e+18       0.076704       0.846857       0.066224
# 1.0007114053837948e+18       0.000000       0.313810       0.016190
# 1.0007450962691808e+18       0.036560       0.752370       0.181070
# 1.0008147556641504e+18       0.437000       0.563000       0.000000
# ...                               ...            ...            ...
# 989582592.0                  0.008140       0.949210       0.042660
# 990811135.0                  0.056061       0.867040       0.036505
# 991741717.0                  0.069697       0.810444       0.089525
# 994072862.0                  0.106200       0.694840       0.138950
# 99757609.0                   0.099054       0.834957       0.065967
#
#                         user_comp_mean  user_arts_&_culture_mean  \
# id
# ...

# %%
df1.columns
# Out:
# Index(['id', 'user_neg_mean', 'user_neu_mean', 'user_pos_mean',
#        'user_comp_mean', 'user_arts_&_culture_mean',
#        'user_business_&_entrepreneurs_mean',
#        'user_celebrity_&_pop_culture_mean', 'user_diaries_&_daily_life_mean',
#        'user_family_mean', 'user_fashion_&_style_mean',
#        'user_film_tv_&_video_mean', 'user_fitness_&_health_mean',
#        'user_food_&_dining_mean', 'user_gaming_mean',
#        'user_learning_&_educational_mean', 'user_music_mean',
#        'user_news_&_social_concern_mean', 'user_other_hobbies_mean',
#        'user_relationships_mean', 'user_science_&_technology_mean',
#        'user_sports_mean', 'user_travel_&_adventure_mean',
#        'user_youth_&_student_life_mean', 'user_hateful_mean',
#        'user_targeted_mean', 'user_aggressive_mean', 'user_joy_mean',
#        'user_sadness_mean', 'user_others_mean', 'user_anger_mean',
#        'user_surprise_mean', 'user_disgust_mean', 'user_fear_mean',
#        'user_topic_mode'],
# ...

# %%
len(df1)
# Out:
# 3863

# %%
df1.index
# Out:
# Int64Index([              17773,              683063,              708813,
#                          867681,             1524781,             1550461,
#                         2266321,             2622551,             7611312,
#                         8099122,
#             ...
#             1557511836118966272, 1557743537588170752, 1557797267528097792,
#             1558147135681478912, 1558443032382414848, 1558543081594650624,
#             1558545466039599104, 1559188363554463488, 1559196468854112512,
#             1559276934806266112],
#            dtype='int64', name='id', length=6714)

# %%
df1['id'] = df1.index.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6cc0aa773069> in <module>
# ----> 1 df1['id'] = df1.index.reset_index()
#
# NameError: name 'df1' is not defined

# %%
df1
# Out:
#                       id  user_neg_mean  user_neu_mean  user_pos_mean  \
# 0    1072373029517316096       0.107141       0.751606       0.090707
# 1     930520648245497856       0.090370       0.758020       0.081630
# 2    1556317842160717825       0.127367       0.752908       0.119724
# 3    1318942066517344258       0.056110       0.816600       0.117310
# 4    1210180533050904577       0.108950       0.764760       0.116310
# ..                   ...            ...            ...            ...
# 857  1446098596001161224       0.057670       0.743930       0.098380
# 858  1205581929283817477       0.083560       0.698340       0.088100
# 859  1303745818734866433       0.137890       0.704640       0.087490
# 860  1486397215673397251       0.098120       0.770460       0.091440
# 861  1349059004761337867       0.437000       0.563000       0.000000
#
#      user_comp_mean  user_arts_&_culture_mean  \
# 0         -0.030808                  0.018257
# ...

# %%
df1.columns
# Out:
# Index(['id', 'user_neg_mean', 'user_neu_mean', 'user_pos_mean',
#        'user_comp_mean', 'user_arts_&_culture_mean',
#        'user_business_&_entrepreneurs_mean',
#        'user_celebrity_&_pop_culture_mean', 'user_diaries_&_daily_life_mean',
#        'user_family_mean', 'user_fashion_&_style_mean',
#        'user_film_tv_&_video_mean', 'user_fitness_&_health_mean',
#        'user_food_&_dining_mean', 'user_gaming_mean',
#        'user_learning_&_educational_mean', 'user_music_mean',
#        'user_news_&_social_concern_mean', 'user_other_hobbies_mean',
#        'user_relationships_mean', 'user_science_&_technology_mean',
#        'user_sports_mean', 'user_travel_&_adventure_mean',
#        'user_youth_&_student_life_mean', 'user_hateful_mean',
#        'user_targeted_mean', 'user_aggressive_mean', 'user_joy_mean',
#        'user_sadness_mean', 'user_others_mean', 'user_anger_mean',
#        'user_surprise_mean', 'user_disgust_mean', 'user_fear_mean',
# ...

# %%
df1.reset_index(inplace = True)

# %%
len(df)
# Out:
# 303701

# %%
len(df1)
# Out:
# 2914

# %%
df1 = df1.drop(['Unnamed: 0'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-646fbd4d41bf> in <module>
# ----> 1 df1 = df1.drop(['Unnamed: 0'], axis=1)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
#to csv informer/infector
# df1.to_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_features_mean.csv')
# to csv retweeter
df1.to_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /raw_data (1)/raw_data/historic tweets/historic_mean_english.csv')

# %%
df1
# Out:
#                        id  user_neg_mean  user_neu_mean  user_pos_mean  \
# 0                   82283       0.009510       0.607940       0.012550
# 1                  639673       0.001040       0.504010       0.000000
# 2                  640893       0.106040       0.723899       0.139747
# 3                  989231       0.088150       0.728320       0.153580
# 4                 1233241       0.082070       0.893080       0.024850
# ...                   ...            ...            ...            ...
# 3858  1554254229056983040       0.038180       0.919580       0.012240
# 3859  1555233408800161793       0.008296       0.674735       0.051663
# 3860  1556317842160717825       0.127367       0.752908       0.119724
# 3861  1556624852852781057       0.013649       0.716412       0.094680
# 3862  1558147135681478659       0.088424       0.791960       0.119586
#
#       user_comp_mean  user_arts_&_culture_mean  \
# 0          -0.003227                  0.031967
# ...
