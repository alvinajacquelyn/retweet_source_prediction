# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 
import json
import csv
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_year_project/merging_features/infector_all_features.csv')

# %%
df.rename(columns={ df.columns[0]: "retweeter_id" }, inplace = True)
# df.columns.values[0]
df
# Out:
#              retweeter_id                    hashtag            retweeter  \
# 0     1195757010723184640            #EnoughIsEnough             48959540
# 1              1159881870        #CostOfLivingCrisis  1051124876315152384
# 2      930520648245497856  #GetBackToWorkYouFatPonce  1272622039220629504
# 3               303324434  #GetBackToWorkYouFatPonce           2912306735
# 4               345462945            #EnoughIsEnough  1072373029517316096
# ...                   ...                        ...                  ...
# 2266            241565399  #GetBackToWorkYouFatPonce             64713130
# 2267             27635954  #GetBackToWorkYouFatPonce            132183460
# 2268  1437493805796798472  #GetBackToWorkYouFatPonce             23505270
# 2269            312099373  #GetBackToWorkYouFatPonce            558597445
# 2270  1517879830544629760  #GetBackToWorkYouFatPonce  1440330790101929998
#
#       UsM_deltaDays  UsM_statusesCount  UsM_followersCount  \
# ...

# %%
hashtags = ['#VoteThemOut',
            # '#ToryScumOut',
            'F1',
            'Lisa',
            '#EnoughIsEnough',
            '#EnergyPrices',
            '#iOS16',
            '#taiwan',
            '#onepiece',
            '#CostOfLivingCrisis',
            '#GetBackToWorkYouFatPonce', 
            # '#ClosingCeremony',
            '#BookLoversDay',
            '#biden']

            
hashtag_labels =  list(df["hashtag"])
index_remove = []
for idx in df.index:
    # print(df['hashtag'][idx])
    if (df['hashtag'][idx]) not in hashtags:
      # print("removed")
      index_remove.append(idx)

print(len(df))
len(index_remove)
# Out:
# 2271
# 249

# %%
df2 = df.drop(index_remove)
df2
# Out:
#              retweeter_id                    hashtag            retweeter  \
# 0     1195757010723184640            #EnoughIsEnough             48959540
# 1              1159881870        #CostOfLivingCrisis  1051124876315152384
# 2      930520648245497856  #GetBackToWorkYouFatPonce  1272622039220629504
# 3               303324434  #GetBackToWorkYouFatPonce           2912306735
# 4               345462945            #EnoughIsEnough  1072373029517316096
# ...                   ...                        ...                  ...
# 2266            241565399  #GetBackToWorkYouFatPonce             64713130
# 2267             27635954  #GetBackToWorkYouFatPonce            132183460
# 2268  1437493805796798472  #GetBackToWorkYouFatPonce             23505270
# 2269            312099373  #GetBackToWorkYouFatPonce            558597445
# 2270  1517879830544629760  #GetBackToWorkYouFatPonce  1440330790101929998
#
#       UsM_deltaDays  UsM_statusesCount  UsM_followersCount  \
# ...

# %%
df2 = df2.reset_index(drop=True)
df2
# Out:
#              retweeter_id                    hashtag            retweeter  \
# 0     1195757010723184640            #EnoughIsEnough             48959540
# 1              1159881870        #CostOfLivingCrisis  1051124876315152384
# 2      930520648245497856  #GetBackToWorkYouFatPonce  1272622039220629504
# 3               303324434  #GetBackToWorkYouFatPonce           2912306735
# 4               345462945            #EnoughIsEnough  1072373029517316096
# ...                   ...                        ...                  ...
# 2017            241565399  #GetBackToWorkYouFatPonce             64713130
# 2018             27635954  #GetBackToWorkYouFatPonce            132183460
# 2019  1437493805796798472  #GetBackToWorkYouFatPonce             23505270
# 2020            312099373  #GetBackToWorkYouFatPonce            558597445
# 2021  1517879830544629760  #GetBackToWorkYouFatPonce  1440330790101929998
#
#       UsM_deltaDays  UsM_statusesCount  UsM_followersCount  \
# ...

# %%
# df2.to_csv('/content/drive/MyDrive/Colab Notebooks/Ziwen /features/sta/infector_all_features_new_FINAL.csv')

# %%
texts = []

user_neg_mean   = []
user_neu_mean	= []
user_pos_mean	= []
user_comp_mean	= []

user_arts_culture_mean	= []
user_business_entrepreneurs_mean	= []
user_celebrity_pop_culture_mean	=[] 
user_diaries_daily_life_mean	= []
user_family_mean	= []
user_fashion_style_mean	= []
user_film_tv_video_mean	=[]
user_fitness_health_mean	=[]
user_food_dining_mean	= []
user_gaming_mean	=[] 
user_learning_educational_mean	=[] 
user_music_mean	=[] 
user_news_social_concern_mean	= [] 
user_other_hobbies_mean	= [] 
user_relationships_mean	= [] 
user_science_technology_mean	= []
user_sports_mean	=[] 
user_travel_adventure_mean	= []
user_youth_student_life_mean  = []

user_hateful_mean	= [] 
user_targeted_mean	= [] 
user_aggressive_mean	= [] 
user_joy_mean	= [] 
user_sadness_mean	=[]
user_others_mean	= [] 
user_anger_mean	= [] 
user_surprise_mean	= [] 
user_disgust_mean	= []
user_fear_mean	= [] 

user_Kincaid_mean	= [] 
user_ARI_mean	= [] 
user_ColemanLiau_mean	= [] 
user_FleschReadingEase_mean	= [] 
user_GunningFogIndex_mean	= [] 
user_LIX_mean	= [] 
user_SMOGIndex_mean	= [] 
user_RIX_mean	= [] 
user_DaleChallIndex_mean	= [] 
user_characters_per_word_mean	= [] 
user_syll_per_word_mean	= [] 
user_words_per_sentence_mean	= [] 
user_sentences_per_paragraph_mean	= [] 
user_type_token_ratio_mean	= [] 
user_characters_mean	= [] 
user_syllables_mean	= [] 
user_words_mean	= [] 
user_wordtypes_mean	= [] 
user_sentences_mean	= [] 
user_paragraphs_mean	= [] 
user_long_words_mean	= [] 
user_complex_words_mean	= [] 
user_complex_words_dc_mean	= [] 

user_sentiment_mode	= [] 
user_topic_mode	= [] 
politeness	= [] 
cardiff_tokens	= [] 
offensive	= [] 
irony	= [] 
emoji	= [] 
gender= [] 
subjectivity = []
grammar = []

# %%
df2
# Out:
#              retweeter_id                    hashtag            retweeter  \
# 0     1195757010723184640            #EnoughIsEnough             48959540
# 1              1159881870        #CostOfLivingCrisis  1051124876315152384
# 2      930520648245497856  #GetBackToWorkYouFatPonce  1272622039220629504
# 3               303324434  #GetBackToWorkYouFatPonce           2912306735
# 4               345462945            #EnoughIsEnough  1072373029517316096
# ...                   ...                        ...                  ...
# 2017            241565399  #GetBackToWorkYouFatPonce             64713130
# 2018             27635954  #GetBackToWorkYouFatPonce            132183460
# 2019  1437493805796798472  #GetBackToWorkYouFatPonce             23505270
# 2020            312099373  #GetBackToWorkYouFatPonce            558597445
# 2021  1517879830544629760  #GetBackToWorkYouFatPonce  1440330790101929998
#
#       UsM_deltaDays  UsM_statusesCount  UsM_followersCount  \
# ...

# %%
print(len(gender))
# Out:
# 0

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=2022, step=1)

# %%
indexes_with_tags = []

for idx in df2.index:
    
    hash = df2['hashtag'][idx]
    df3 = pd.read_csv( f'/content/drive/MyDrive/Colab Notebooks/final_year_project/run_tweet_features/5/{hash}_tweet_features_with_subjectivitygrammar.csv')
    # print(df3)
    # break
    # print(df2)
    
    for x in df3.index:

        user_data_retweeter_id = str(df2['retweeter_id'][idx])
        tweet_data_user_id = str(df3['user_id'][x])
       

        if user_data_retweeter_id == tweet_data_user_id:
            print(df2['hashtag'][idx], idx,  df2['retweeter_id'][idx], df3['user_id'][x])
        # print("hi", (df3['text'][x]))
            texts.append(df3['text'][x])
        

            user_neg_mean.append(df3['user_neg_mean'][x])
            user_neu_mean.append(df3['user_neu_mean'][x])
            user_pos_mean.append(df3['user_pos_mean'][x])
            user_comp_mean.append(df3['user_comp_mean'][x])

            user_arts_culture_mean.append(df3['user_arts_&_culture_mean'][x])
            user_business_entrepreneurs_mean.append(df3['user_business_&_entrepreneurs_mean'][x])
            user_celebrity_pop_culture_mean.append(df3['user_celebrity_&_pop_culture_mean'][x]) 
            user_diaries_daily_life_mean.append(df3['user_diaries_&_daily_life_mean'][x])
            user_family_mean.append(df3['user_family_mean'][x])
            user_fashion_style_mean.append(df3['user_fashion_&_style_mean'][x])
            user_film_tv_video_mean.append(df3['user_film_tv_&_video_mean'][x])
            user_fitness_health_mean.append(df3['user_fitness_&_health_mean'][x])
            user_food_dining_mean.append(df3['user_food_&_dining_mean'][x])
            user_gaming_mean.append(df3['user_gaming_mean'][x])
            user_learning_educational_mean.append(df3['user_learning_&_educational_mean'][x])
            user_music_mean.append(df3['user_music_mean'][x])
            user_news_social_concern_mean.append(df3['user_news_&_social_concern_mean'][x]) 
            user_other_hobbies_mean.append(df3['user_other_hobbies_mean'][x]) 
            user_relationships_mean.append(df3['user_relationships_mean'][x])
            user_science_technology_mean.append(df3['user_science_&_technology_mean'][x])
            user_sports_mean.append(df3['user_sports_mean'][x])
            user_travel_adventure_mean.append(df3['user_travel_&_adventure_mean'][x])
            user_youth_student_life_mean.append(df3['user_youth_&_student_life_mean'][x])

            user_hateful_mean.append(df3['user_hateful_mean'][x]) 
            user_targeted_mean.append(df3['user_targeted_mean'][x]) 
            user_aggressive_mean.append(df3['user_aggressive_mean'][x]) 
            user_joy_mean.append(df3['user_joy_mean'][x]) 
            user_sadness_mean.append(df3['user_sadness_mean'][x])
            user_others_mean.append(df3['user_others_mean'][x])
            user_anger_mean.append(df3['user_anger_mean'][x])
            user_surprise_mean.append(df3['user_surprise_mean'][x]) 
            user_disgust_mean.append(df3['user_disgust_mean'][x])
            user_fear_mean.append(df3['user_fear_mean'][x]) 

            user_Kincaid_mean.append(df3['user_Kincaid_mean'][x])
            user_ARI_mean.append(df3['user_ARI_mean'][x])
            user_ColemanLiau_mean.append(df3['user_Coleman-Liau_mean'][x]) 
            user_FleschReadingEase_mean.append(df3['user_FleschReadingEase_mean'][x]) 
            user_GunningFogIndex_mean.append(df3['user_GunningFogIndex_mean'][x])
            user_LIX_mean.append(df3['user_LIX_mean'][x])
            user_SMOGIndex_mean.append(df3['user_SMOGIndex_mean'][x])
            user_RIX_mean.append(df3['user_RIX_mean'][x]) 
            user_DaleChallIndex_mean.append(df3['user_DaleChallIndex_mean'][x]) 
            user_characters_per_word_mean.append(df3['user_characters_per_word_mean'][x])
            user_syll_per_word_mean.append(df3['user_syll_per_word_mean'][x]) 
            user_words_per_sentence_mean.append(df3['user_words_per_sentence_mean'][x])
            user_sentences_per_paragraph_mean.append(df3['user_sentences_per_paragraph_mean'][x]) 
            user_type_token_ratio_mean.append(df3['user_type_token_ratio_mean'][x]) 
            user_characters_mean.append(df3['user_characters_mean'][x])
            user_syllables_mean.append(df3['user_syllables_mean'][x])
            user_words_mean.append(df3['user_words_mean'][x])
            user_wordtypes_mean.append(df3['user_wordtypes_mean'][x])
            user_sentences_mean.append(df3['user_sentences_mean'][x])
            user_paragraphs_mean.append(df3['user_paragraphs_mean'][x])
            user_long_words_mean.append(df3['user_long_words_mean'][x])
            user_complex_words_mean.append(df3['user_complex_words_mean'][x])
            user_complex_words_dc_mean.append(df3['user_complex_words_dc_mean'][x]) 

            user_sentiment_mode.append(df3['user_sentiment_mode'][x])
            user_topic_mode.append(df3['user_topic_mode'][x])
            politeness.append(df3['politeness'][x])
            cardiff_tokens.append(df3['cardiff_tokens'][x])
            offensive.append(df3['offensive'][x])
            irony.append(df3['irony'][x])
            emoji.append(df3['emoji'][x])
            gender.append(df3['gender'][x]) 
            subjectivity.append(df3['tweet_subjectivity'][x])
            grammar.append(df3['tweet_grammar'][x])

            # print(idx)
            indexes_with_tags.append(idx)
            break



print(len(texts))
print(len(user_neg_mean))
print(df2.shape)
# print(len(indexes))
# Out:
# #EnoughIsEnough 0 1195757010723184640 1195757010723184640
# #CostOfLivingCrisis 1 1159881870 1159881870
# #GetBackToWorkYouFatPonce 2 930520648245497856 930520648245497856
# #GetBackToWorkYouFatPonce 3 303324434 303324434
# #EnoughIsEnough 4 345462945 345462945
# #EnoughIsEnough 5 1147649644492730373 1147649644492730373
# #EnoughIsEnough 6 1420351245819207681 1420351245819207681
# #CostOfLivingCrisis 7 1190933596921638912 1190933596921638912
# #EnoughIsEnough 8 219266194 219266194
# #EnoughIsEnough 9 24403686 24403686
# #EnoughIsEnough 10 1542616732556304386 1542616732556304386
# #EnoughIsEnough 11 1455990635111059456 1455990635111059456
# #EnoughIsEnough 12 103989424 103989424
# #EnoughIsEnough 13 1199779543533473792 1199779543533473792
# #EnoughIsEnough 14 527674798 527674798
# #EnoughIsEnough 15 1284939407494205443 1284939407494205443
# #EnoughIsEnough 16 1242670502084333568 1242670502084333568
# #EnoughIsEnough 17 2272185878 2272185878
# ...

# %%
print(len(indexes_with_tags)) #(7814, 22)
# Out:
# 1970

# %%
df2.index.name = 'index'

# %%
df2
# Out:
#               retweeter_id                    hashtag            retweeter  \
# index
# 0      1195757010723184640            #EnoughIsEnough             48959540
# 1               1159881870        #CostOfLivingCrisis  1051124876315152384
# 2       930520648245497856  #GetBackToWorkYouFatPonce  1272622039220629504
# 3                303324434  #GetBackToWorkYouFatPonce           2912306735
# 4                345462945            #EnoughIsEnough  1072373029517316096
# ...                    ...                        ...                  ...
# 2017             241565399  #GetBackToWorkYouFatPonce             64713130
# 2018              27635954  #GetBackToWorkYouFatPonce            132183460
# 2019   1437493805796798472  #GetBackToWorkYouFatPonce             23505270
# 2020             312099373  #GetBackToWorkYouFatPonce            558597445
# 2021   1517879830544629760  #GetBackToWorkYouFatPonce  1440330790101929998
#
# ...

# %%
templist = []
# print(type(templist[0]))
print(type(df2.index.values[0]))
for idx in df2.index.values:
    if idx not in  indexes_with_tags:
        print("Yes")
        templist.append(idx)


templist
# Out:
# <class 'numpy.int64'>
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# [663,
#  667,
#  668,
#  669,
#  673,
#  674,
#  676,
#  677,
#  678,
#  679,
#  683,
#  693,
#  701,
#  702,
#  705,
#  708,
#  713,
#  714,
#  717,
#  722,
#  723,
#  724,
#  725,
#  727,
#  728,
#  733,
#  738,
#  742,
#  750,
#  753,
#  754,
#  757,
#  759,
#  770,
#  772,
#  776,
#  777,
#  778,
#  780,
#  784,
#  788,
#  789,
#  790,
#  791,
#  796,
#  797,
#  798,
#  801,
#  807,
#  811,
#  815,
#  818]

# %%
df2= df2.drop(templist)
df2.shape
# Out:
# (1970, 28)

# %%
df2['retweeter_tweet'] = texts

df2['user_neg_mean'] = user_neg_mean
df2['user_neu_mean'] = user_neu_mean
df2['user_pos_mean'] = user_pos_mean
df2['user_comp_mean'] = user_comp_mean

df2['user_arts_&_culture_mean'] = user_arts_culture_mean
df2['user_business_&_entrepreneurs_mean'] = user_business_entrepreneurs_mean
df2['user_celebrity_&_pop_culture_mean'] = user_celebrity_pop_culture_mean
df2['user_diaries_&_daily_life_mean'] = user_diaries_daily_life_mean
df2['user_family_mean'] = user_family_mean
df2['user_fashion_&_style_mean'] = user_fashion_style_mean
df2['user_film_tv_&_video_mean'] = user_film_tv_video_mean
df2['user_fitness_&_health_mean'] = user_fitness_health_mean
df2['user_food_&_dining_mean'] = user_food_dining_mean
df2['user_gaming_mean'] = user_gaming_mean
df2['user_learning_&_educational_mean'] = user_learning_educational_mean
df2['user_music_mean'] = user_music_mean
df2['user_news_&_social_concern_mean'] = user_news_social_concern_mean
df2['user_other_hobbies_mean'] = user_other_hobbies_mean
df2['user_relationships_mean'] = user_relationships_mean
df2['user_science_&_technology_mean'] = user_science_technology_mean
df2['user_sports_mean'] = user_sports_mean
df2['user_travel_&_adventure_mean'] = user_travel_adventure_mean
df2['user_youth_&_student_life_mean'] = user_youth_student_life_mean
df2['user_hateful_mean'] = user_hateful_mean
df2['user_targeted_mean'] = user_targeted_mean
df2['user_aggressive_mean'] = user_aggressive_mean
df2['user_joy_mean'] = user_joy_mean
df2['user_sadness_mean'] = user_sadness_mean
df2['user_others_mean'] = user_others_mean
df2['user_anger_mean'] = user_anger_mean
df2['user_surprise_mean'] = user_surprise_mean
df2['user_disgust_mean'] = user_disgust_mean
df2['user_fear_mean'] = user_fear_mean

df2['user_Kincaid_mean'] = user_Kincaid_mean
df2['user_ARI_mean'] = user_ARI_mean
df2['user_Coleman-Liau_mean'] = user_ColemanLiau_mean
df2['user_FleschReadingEase_mean'] = user_FleschReadingEase_mean
df2['user_GunningFogIndex_mean'] = user_GunningFogIndex_mean
df2['user_LIX_mean'] = user_LIX_mean
df2['user_SMOGIndex_mean'] = user_SMOGIndex_mean
df2['user_RIX_mean'] = user_RIX_mean
df2['user_DaleChallIndex_mean'] = user_DaleChallIndex_mean
df2['user_characters_per_word_mean'] = user_characters_per_word_mean
df2['user_syll_per_word_mean'] = user_syll_per_word_mean
df2['user_words_per_sentence_mean'] = user_words_per_sentence_mean
df2['user_sentences_per_paragraph_mean'] = user_sentences_per_paragraph_mean
df2['user_type_token_ratio_mean'] = user_type_token_ratio_mean
df2['user_characters_mean'] = user_characters_mean
df2['user_syllables_mean'] = user_syllables_mean
df2['user_words_mean'] = user_words_mean
df2['user_wordtypes_mean'] = user_wordtypes_mean
df2['user_sentences_mean'] = user_sentences_mean
df2['user_paragraphs_mean'] = user_paragraphs_mean
df2['user_long_words_mean'] = user_long_words_mean
df2['user_complex_words_mean'] = user_complex_words_mean
df2['user_complex_words_dc_mean'] = user_complex_words_dc_mean

df2['user_sentiment_mode'] = user_sentiment_mode
df2['user_topic_mode'] = user_topic_mode
df2['politeness'] = politeness
df2['cardiff_tokens'] = cardiff_tokens
df2['offensive'] = offensive
df2['irony'] = irony
df2['emoji'] = emoji
df2['gender'] = gender
df2['tweet_subjectivity']  = subjectivity
df2['tweet_grammar'] = grammar

# %%
df2
# Out:
#               retweeter_id                    hashtag            retweeter  \
# index
# 0      1195757010723184640            #EnoughIsEnough             48959540
# 1               1159881870        #CostOfLivingCrisis  1051124876315152384
# 2       930520648245497856  #GetBackToWorkYouFatPonce  1272622039220629504
# 3                303324434  #GetBackToWorkYouFatPonce           2912306735
# 4                345462945            #EnoughIsEnough  1072373029517316096
# ...                    ...                        ...                  ...
# 2017             241565399  #GetBackToWorkYouFatPonce             64713130
# 2018              27635954  #GetBackToWorkYouFatPonce            132183460
# 2019   1437493805796798472  #GetBackToWorkYouFatPonce             23505270
# 2020             312099373  #GetBackToWorkYouFatPonce            558597445
# 2021   1517879830544629760  #GetBackToWorkYouFatPonce  1440330790101929998
#
# ...

# %%
df2.to_csv('/content/drive/MyDrive/Colab Notebooks/final_year_project/merging_features/infector_all_features_tweettext_new_FINAL.csv')
